# %% [markdown]
# ## Import libraries

# %%
# Base libraries
import pandas as pd
import numpy as np
from pyforest import *

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# sklearn
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# ## Exploring the database

# %%
# Open the excel database 
# In Row the 184 countries and the years
health = pd.read_excel('C:/Users/igrav/Desktop/ironhack/Lecture/Week_9/Project/data_origine/World bank/Data_Health_Source3.xlsx')
pd.set_option('display.max_columns', None)
health.head()
# Out:
#   Country Name Country Code  Year  Birth rate (per 1,000 people)  \
# 0    Australia          AUS  2015                           12.9
# 1    Australia          AUS  2014                           13.2
# 2    Australia          AUS  2013                           13.3
# 3    Australia          AUS  2012                           13.7
# 4    Australia          AUS  2011                           13.6
#
#    Cause of death, by communicable diseasesl and nutrition conditions (% of total)  \
# 0                                           4.569557
# 1                                           4.262027
# 2                                           4.262027
# 3                                           4.262027
# 4                                           4.262027
#
#    Cause of death, by injury (% of total)  \
# 0                                5.857025
# 1                                5.722820
# 2                                5.722820
# 3                                5.722820
# 4                                5.722820
#
#    Cause of death, by non-communicable diseases (% of total)  \
# 0                                          89.573419
# 1                                          90.015155
# 2                                          90.015155
# 3                                          90.015155
# 4                                          90.015155
#
#    Current health expenditure (% of GDP)  \
# 0                               9.327589
# 1                               9.035971
# 2                               8.761164
# 3                               8.675648
# 4                               8.541538
#
#    Current health expenditure per capita, PPP ( $)  \
# 0                                      4392.074219
# 1                                      4283.142090
# 2                                      4161.620117
# 3                                      3778.473633
# 4                                      3760.759766
#
#    Death rate (per 1,000 people)  \
# 0                            6.6
# 1                            6.6
# 2                            6.4
# 3                            6.6
# 4                            6.6
#
#    Diabetes prevalence (% of population ages 20 to 79)  \
# 0                                                6.5
# 1                                                6.5
# 2                                                6.5
# 3                                                6.5
# 4                                                6.6
#
#    Domestic general government health expenditure (% of GDP)  \
# 0                                           6.383698
# 1                                           6.100497
# 2                                           5.937055
# 3                                           6.180068
# 4                                           6.257556
#
#    Domestic general government health expenditure per capita, PPP ($)  \
# 0                                        3005.886782
# 1                                        2891.697554
# 2                                        2820.146826
# 3                                        2691.582711
# 4                                        2755.143820
#
#    Domestic private health expenditure per capita, PPP  ($)  \
# 0                                        1386.187406
# 1                                        1391.444573
# 2                                        1341.473459
# 3                                        1086.891027
# 4                                        1005.615985
#
#    Fertility rate, total (births per woman)  GNI per capita (US$)  \
# 0                                     1.814               60490.0
# 1                                     1.826               65180.0
# 2                                     1.855               66050.0
# 3                                     1.920               60260.0
# 4                                     1.926               50380.0
#
#    Hospital beds (per 1,000 people)  Human capital index (HCI) (scale 0-1)  \
# 0                              3.82                               0.754844
# 1                              3.79                               0.754844
# 2                              3.74                               0.754844
# 3                              3.75                               0.754844
# 4                              3.79                               0.754844
#
#    Immunization, Pol3 (% children)  \
# 0                             93.0
# 1                             92.0
# 2                             91.0
# 3                             92.0
# 4                             92.0
#
#    Incidence of tuberculosis (per 100,000 people)  \
# 0                                             6.0
# 1                                             6.5
# 2                                             6.2
# 3                                             6.6
# 4                                             6.3
#
#    Life expectancy at birth, total (years)  \
# 0                                82.400000
# 1                                82.300000
# 2                                82.148780
# 3                                82.046341
# 4                                81.895122
#
#    Lifetime risk of maternal death (%)  \
# 0                             0.012233
# 1                             0.011954
# 2                             0.011438
# 3                             0.011079
# 4                             0.011219
#
#    Maternal mortality ratio ( per 100,000 live births)  \
# 0                                                6.0
# 1                                                6.0
# 2                                                6.0
# 3                                                6.0
# 4                                                6.0
#
#    Mortality caused by road traffic injury (per 100,000 people)  \
# 0                                                5.2
# 1                                                5.4
# 2                                                5.3
# 3                                                5.8
# 4                                                5.9
#
#    Mortality from CVD, cancer, diabetes or CRD (%)  \
# 0                                              9.3
# 1                                              9.3
# 2                                              9.3
# 3                                              9.3
# 4                                              9.8
#
#    Mortality rate, infant (per 1,000 live births)  Nurses (per 1,000 people)  \
# 0                                             3.3                    12.2016
# 1                                             3.4                    12.1107
# 2                                             3.5                    11.9398
# 3                                             3.6                    10.1433
# 4                                             3.8                    10.8124
#
#    Out-of-pocket expenditure (% of current health expenditure)  \
# 0                                          18.741520
# 1                                          19.401701
# 2                                          19.504166
# 3                                          19.934338
# 4                                          19.172483
#
#    Out-of-pocket expenditure per capita, PPP ($)  \
# 0                                     823.141488
# 1                                     831.002422
# 2                                     811.689231
# 3                                     753.213764
# 4                                     721.031068
#
#    People using drinking water services (%)  Physicians (per 1,000 people)  \
# 0                                 99.970006                         3.4886
# 1                                 99.961479                         3.4314
# 2                                 99.909588                         3.3530
# 3                                 99.900767                         3.2858
# 4                                 99.891969                         3.2878
#
#    Population growth (annual %)  GDP per capita, PPP ($)  Population  \
# 0                      1.439217             44493.480894    24190907
# 1                      1.491566             43923.258269    23815995
# 2                      1.721151             43547.197484    23475686
# 3                      1.745820             43118.086127    23128129
# 4                      1.389527             42754.456286    22733465
#
#       GDP (B$)  Prevalence of tobacco  (%)  \
# 0  1076.337658                   15.700000
# 1  1046.076099                   18.333333
# 2  1022.300334                   18.333333
# 3   997.240658                   18.333333
# 4   971.956936                   18.333333
#
#    Prevalence of overweight (% of adults)  \
# 0                                    64.0
# 1                                    63.6
# 2                                    63.1
# 3                                    62.7
# 4                                    62.2
#
#    Public spending on education (% of GDP)  Rural population (%)  \
# 0                                  5.31584                14.299
# 1                                  5.16469                14.398
# 2                                  5.22924                14.498
# 3                                  4.86788                14.598
# 4                                  5.06995                14.700
#
#    School enrollment, tertiary (%)  Suicide mortality rate (per 100,000)  \
# 0                       118.610863                                  13.2
# 1                       118.610863                                  12.7
# 2                       118.610863                                  11.5
# 3                       118.610863                                  11.7
# 4                       118.610863                                  11.2
#
#    Total alcohol consumption per capita   % of adults with hypertension  \
# 0                              10.830000                           51.7
# 1                              11.766667                           52.5
# 2                              11.766667                           53.2
# 3                              11.766667                           53.7
# 4                              11.766667                           54.0
#
#    Tuberculosis death rate (per 100,000 people)  Unemployment, total (%)
# 0                                          0.22                     6.05
# 1                                          0.20                     6.08
# 2                                          0.22                     5.66
# 3                                          0.16                     5.22
# 4                                          0.25                     5.08

# %%
health.shape
# Out:
# (602, 45)

# %% [markdown]
# ## Pivot and Melt

# %%
# years = [i for i in np.arange(2002,2022,1)]

# %%
# health.melt(health, id_vars=['Country_Name'], value_vars=[(years)])

# %%
health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602 entries, 0 to 601
# Data columns (total 45 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   Country Name                                                                     602 non-null    object
#  1   Country Code                                                                     602 non-null    object
#  2   Year                                                                             602 non-null    int64
#  3   Birth rate (per 1,000 people)                                                    602 non-null    float64
#  4   Cause of death, by communicable diseasesl and nutrition conditions (% of total)  602 non-null    float64
#  5   Cause of death, by injury (% of total)                                           602 non-null    float64
#  6   Cause of death, by non-communicable diseases (% of total)                        602 non-null    float64
#  7   Current health expenditure (% of GDP)                                            602 non-null    float64
#  8   Current health expenditure per capita, PPP ( $)                                  602 non-null    float64
#  9   Death rate (per 1,000 people)                                                    602 non-null    float64
#  10  Diabetes prevalence (% of population ages 20 to 79)                              602 non-null    float64
#  11  Domestic general government health expenditure (% of GDP)                        602 non-null    float64
#  12  Domestic general government health expenditure per capita, PPP ($)               602 non-null    float64
#  13  Domestic private health expenditure per capita, PPP  ($)                         602 non-null    float64
#  14  Fertility rate, total (births per woman)                                         602 non-null    float64
#  15  GNI per capita (US$)                                                             602 non-null    float64
#  16  Hospital beds (per 1,000 people)                                                 602 non-null    float64
#  17  Human capital index (HCI) (scale 0-1)                                            602 non-null    float64
#  18  Immunization, Pol3 (% children)                                                  602 non-null    float64
#  19  Incidence of tuberculosis (per 100,000 people)                                   602 non-null    float64
#  20  Life expectancy at birth, total (years)                                          602 non-null    float64
#  21  Lifetime risk of maternal death (%)                                              602 non-null    float64
#  22  Maternal mortality ratio ( per 100,000 live births)                              602 non-null    float64
#  23  Mortality caused by road traffic injury (per 100,000 people)                     602 non-null    float64
#  24  Mortality from CVD, cancer, diabetes or CRD (%)                                  602 non-null    float64
#  25  Mortality rate, infant (per 1,000 live births)                                   602 non-null    float64
#  26  Nurses (per 1,000 people)                                                        602 non-null    float64
#  27  Out-of-pocket expenditure (% of current health expenditure)                      602 non-null    float64
#  28  Out-of-pocket expenditure per capita, PPP ($)                                    602 non-null    float64
#  29  People using drinking water services (%)                                         602 non-null    float64
#  30  Physicians (per 1,000 people)                                                    602 non-null    float64
#  31  Population growth (annual %)                                                     602 non-null    float64
#  32  GDP per capita, PPP ($)                                                          602 non-null    float64
#  33  Population                                                                       602 non-null    int64
#  34  GDP (B$)                                                                         602 non-null    float64
#  35  Prevalence of tobacco  (%)                                                       602 non-null    float64
#  36  Prevalence of overweight (% of adults)                                           602 non-null    float64
#  37  Public spending on education (% of GDP)                                          602 non-null    float64
#  38  Rural population (%)                                                             602 non-null    float64
#  39  School enrollment, tertiary (%)                                                  602 non-null    float64
#  40  Suicide mortality rate (per 100,000)                                             602 non-null    float64
#  41  Total alcohol consumption per capita                                             602 non-null    float64
#  42  % of adults with hypertension                                                    602 non-null    float64
#  43  Tuberculosis death rate (per 100,000 people)                                     602 non-null    float64
#  44  Unemployment, total (%)                                                          602 non-null    float64
# dtypes: float64(41), int64(2), object(2)
# memory usage: 211.8+ KB

# %%
health = health.apply(lambda x : x.replace("..", np.nan))
health.head()
# Out:
#   Country Name Country Code  Year  Birth rate (per 1,000 people)  \
# 0    Australia          AUS  2015                           12.9
# 1    Australia          AUS  2014                           13.2
# 2    Australia          AUS  2013                           13.3
# 3    Australia          AUS  2012                           13.7
# 4    Australia          AUS  2011                           13.6
#
#    Cause of death, by communicable diseasesl and nutrition conditions (% of total)  \
# 0                                           4.569557
# 1                                           4.262027
# 2                                           4.262027
# 3                                           4.262027
# 4                                           4.262027
#
#    Cause of death, by injury (% of total)  \
# 0                                5.857025
# 1                                5.722820
# 2                                5.722820
# 3                                5.722820
# 4                                5.722820
#
#    Cause of death, by non-communicable diseases (% of total)  \
# 0                                          89.573419
# 1                                          90.015155
# 2                                          90.015155
# 3                                          90.015155
# 4                                          90.015155
#
#    Current health expenditure (% of GDP)  \
# 0                               9.327589
# 1                               9.035971
# 2                               8.761164
# 3                               8.675648
# 4                               8.541538
#
#    Current health expenditure per capita, PPP ( $)  \
# 0                                      4392.074219
# 1                                      4283.142090
# 2                                      4161.620117
# 3                                      3778.473633
# 4                                      3760.759766
#
#    Death rate (per 1,000 people)  \
# 0                            6.6
# 1                            6.6
# 2                            6.4
# 3                            6.6
# 4                            6.6
#
#    Diabetes prevalence (% of population ages 20 to 79)  \
# 0                                                6.5
# 1                                                6.5
# 2                                                6.5
# 3                                                6.5
# 4                                                6.6
#
#    Domestic general government health expenditure (% of GDP)  \
# 0                                           6.383698
# 1                                           6.100497
# 2                                           5.937055
# 3                                           6.180068
# 4                                           6.257556
#
#    Domestic general government health expenditure per capita, PPP ($)  \
# 0                                        3005.886782
# 1                                        2891.697554
# 2                                        2820.146826
# 3                                        2691.582711
# 4                                        2755.143820
#
#    Domestic private health expenditure per capita, PPP  ($)  \
# 0                                        1386.187406
# 1                                        1391.444573
# 2                                        1341.473459
# 3                                        1086.891027
# 4                                        1005.615985
#
#    Fertility rate, total (births per woman)  GNI per capita (US$)  \
# 0                                     1.814               60490.0
# 1                                     1.826               65180.0
# 2                                     1.855               66050.0
# 3                                     1.920               60260.0
# 4                                     1.926               50380.0
#
#    Hospital beds (per 1,000 people)  Human capital index (HCI) (scale 0-1)  \
# 0                              3.82                               0.754844
# 1                              3.79                               0.754844
# 2                              3.74                               0.754844
# 3                              3.75                               0.754844
# 4                              3.79                               0.754844
#
#    Immunization, Pol3 (% children)  \
# 0                             93.0
# 1                             92.0
# 2                             91.0
# 3                             92.0
# 4                             92.0
#
#    Incidence of tuberculosis (per 100,000 people)  \
# 0                                             6.0
# 1                                             6.5
# 2                                             6.2
# 3                                             6.6
# 4                                             6.3
#
#    Life expectancy at birth, total (years)  \
# 0                                82.400000
# 1                                82.300000
# 2                                82.148780
# 3                                82.046341
# 4                                81.895122
#
#    Lifetime risk of maternal death (%)  \
# 0                             0.012233
# 1                             0.011954
# 2                             0.011438
# 3                             0.011079
# 4                             0.011219
#
#    Maternal mortality ratio ( per 100,000 live births)  \
# 0                                                6.0
# 1                                                6.0
# 2                                                6.0
# 3                                                6.0
# 4                                                6.0
#
#    Mortality caused by road traffic injury (per 100,000 people)  \
# 0                                                5.2
# 1                                                5.4
# 2                                                5.3
# 3                                                5.8
# 4                                                5.9
#
#    Mortality from CVD, cancer, diabetes or CRD (%)  \
# 0                                              9.3
# 1                                              9.3
# 2                                              9.3
# 3                                              9.3
# 4                                              9.8
#
#    Mortality rate, infant (per 1,000 live births)  Nurses (per 1,000 people)  \
# 0                                             3.3                    12.2016
# 1                                             3.4                    12.1107
# 2                                             3.5                    11.9398
# 3                                             3.6                    10.1433
# 4                                             3.8                    10.8124
#
#    Out-of-pocket expenditure (% of current health expenditure)  \
# 0                                          18.741520
# 1                                          19.401701
# 2                                          19.504166
# 3                                          19.934338
# 4                                          19.172483
#
#    Out-of-pocket expenditure per capita, PPP ($)  \
# 0                                     823.141488
# 1                                     831.002422
# 2                                     811.689231
# 3                                     753.213764
# 4                                     721.031068
#
#    People using drinking water services (%)  Physicians (per 1,000 people)  \
# 0                                 99.970006                         3.4886
# 1                                 99.961479                         3.4314
# 2                                 99.909588                         3.3530
# 3                                 99.900767                         3.2858
# 4                                 99.891969                         3.2878
#
#    Population growth (annual %)  GDP per capita, PPP ($)  Population  \
# 0                      1.439217             44493.480894    24190907
# 1                      1.491566             43923.258269    23815995
# 2                      1.721151             43547.197484    23475686
# 3                      1.745820             43118.086127    23128129
# 4                      1.389527             42754.456286    22733465
#
#       GDP (B$)  Prevalence of tobacco  (%)  \
# 0  1076.337658                   15.700000
# 1  1046.076099                   18.333333
# 2  1022.300334                   18.333333
# 3   997.240658                   18.333333
# 4   971.956936                   18.333333
#
#    Prevalence of overweight (% of adults)  \
# 0                                    64.0
# 1                                    63.6
# 2                                    63.1
# 3                                    62.7
# 4                                    62.2
#
#    Public spending on education (% of GDP)  Rural population (%)  \
# 0                                  5.31584                14.299
# 1                                  5.16469                14.398
# 2                                  5.22924                14.498
# 3                                  4.86788                14.598
# 4                                  5.06995                14.700
#
#    School enrollment, tertiary (%)  Suicide mortality rate (per 100,000)  \
# 0                       118.610863                                  13.2
# 1                       118.610863                                  12.7
# 2                       118.610863                                  11.5
# 3                       118.610863                                  11.7
# 4                       118.610863                                  11.2
#
#    Total alcohol consumption per capita   % of adults with hypertension  \
# 0                              10.830000                           51.7
# 1                              11.766667                           52.5
# 2                              11.766667                           53.2
# 3                              11.766667                           53.7
# 4                              11.766667                           54.0
#
#    Tuberculosis death rate (per 100,000 people)  Unemployment, total (%)
# 0                                          0.22                     6.05
# 1                                          0.20                     6.08
# 2                                          0.22                     5.66
# 3                                          0.16                     5.22
# 4                                          0.25                     5.08

# %%
health.isna().sum()/len(health)
# Out:
# Country Name                                                                       0.0
# Country Code                                                                       0.0
# Year                                                                               0.0
# Birth rate (per 1,000 people)                                                      0.0
# Cause of death, by communicable diseasesl and nutrition conditions (% of total)    0.0
# Cause of death, by injury (% of total)                                             0.0
# Cause of death, by non-communicable diseases (% of total)                          0.0
# Current health expenditure (% of GDP)                                              0.0
# Current health expenditure per capita, PPP ( $)                                    0.0
# Death rate (per 1,000 people)                                                      0.0
# Diabetes prevalence (% of population ages 20 to 79)                                0.0
# Domestic general government health expenditure (% of GDP)                          0.0
# Domestic general government health expenditure per capita, PPP ($)                 0.0
# Domestic private health expenditure per capita, PPP  ($)                           0.0
# Fertility rate, total (births per woman)                                           0.0
# GNI per capita (US$)                                                               0.0
# Hospital beds (per 1,000 people)                                                   0.0
# Human capital index (HCI) (scale 0-1)                                              0.0
# Immunization, Pol3 (% children)                                                    0.0
# Incidence of tuberculosis (per 100,000 people)                                     0.0
# Life expectancy at birth, total (years)                                            0.0
# Lifetime risk of maternal death (%)                                                0.0
# Maternal mortality ratio ( per 100,000 live births)                                0.0
# Mortality caused by road traffic injury (per 100,000 people)                       0.0
# Mortality from CVD, cancer, diabetes or CRD (%)                                    0.0
# Mortality rate, infant (per 1,000 live births)                                     0.0
# Nurses (per 1,000 people)                                                          0.0
# Out-of-pocket expenditure (% of current health expenditure)                        0.0
# Out-of-pocket expenditure per capita, PPP ($)                                      0.0
# People using drinking water services (%)                                           0.0
# Physicians (per 1,000 people)                                                      0.0
# Population growth (annual %)                                                       0.0
# GDP per capita, PPP ($)                                                            0.0
# Population                                                                         0.0
# GDP (B$)                                                                           0.0
# Prevalence of tobacco  (%)                                                         0.0
# Prevalence of overweight (% of adults)                                             0.0
# Public spending on education (% of GDP)                                            0.0
# Rural population (%)                                                               0.0
# School enrollment, tertiary (%)                                                    0.0
# Suicide mortality rate (per 100,000)                                               0.0
# Total alcohol consumption per capita                                               0.0
# % of adults with hypertension                                                      0.0
# Tuberculosis death rate (per 100,000 people)                                       0.0
# Unemployment, total (%)                                                            0.0
# dtype: float64

# %% [markdown]
# ## Drop the unrelevant columns

# %%
# energy.drop(energy.columns.difference(['country', 'iso_code', 'year',  'population', 'gdp', 'greenhouse_gas_emissions', 'electricity_demand', ' primary_energy_consumption', ' renewables_consumption', ' carbon_intensity_elec', 'low_carbon_consumption', 'fossil_fuel_consumption', 'hydro_consumption', 'biofuel_consumption', 'wind_consumption', 'solar_consumption', 'nuclear_consumption', 'other_renewable_consumption', 'coal_consumption', 'oil_consumption', 'gas_consumption']), 1, inplace=True)
# energy2 = energy[energy.columns.difference(['gdp', 'population'])]

# %%
health.shape
# Out:
# (602, 45)

# %%
health['Life expectancy at birth, total (years)'].describe()
# Out:
# count    602.000000
# mean      78.614937
# std        3.196802
# min       65.529756
# 25%       76.768293
# 50%       79.439024
# 75%       80.986585
# max       83.793902
# Name: Life expectancy at birth, total (years), dtype: float64

# %% [markdown]
# ## Rename & Create relevant new columns for further analysis (C02 per cap, ...)

# %%
health_features = health[health.columns.difference(['Country Name', 'Country Code'])].astype('float')
health_country = health[['Country Name', 'Country Code']]
health = pd.concat([health_country,health_features], axis=1)
health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602 entries, 0 to 601
# Data columns (total 45 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   Country Name                                                                     602 non-null    object
#  1   Country Code                                                                     602 non-null    object
#  2   % of adults with hypertension                                                    602 non-null    float64
#  3   Birth rate (per 1,000 people)                                                    602 non-null    float64
#  4   Cause of death, by communicable diseasesl and nutrition conditions (% of total)  602 non-null    float64
#  5   Cause of death, by injury (% of total)                                           602 non-null    float64
#  6   Cause of death, by non-communicable diseases (% of total)                        602 non-null    float64
#  7   Current health expenditure (% of GDP)                                            602 non-null    float64
#  8   Current health expenditure per capita, PPP ( $)                                  602 non-null    float64
#  9   Death rate (per 1,000 people)                                                    602 non-null    float64
#  10  Diabetes prevalence (% of population ages 20 to 79)                              602 non-null    float64
#  11  Domestic general government health expenditure (% of GDP)                        602 non-null    float64
#  12  Domestic general government health expenditure per capita, PPP ($)               602 non-null    float64
#  13  Domestic private health expenditure per capita, PPP  ($)                         602 non-null    float64
#  14  Fertility rate, total (births per woman)                                         602 non-null    float64
#  15  GDP (B$)                                                                         602 non-null    float64
#  16  GDP per capita, PPP ($)                                                          602 non-null    float64
#  17  GNI per capita (US$)                                                             602 non-null    float64
#  18  Hospital beds (per 1,000 people)                                                 602 non-null    float64
#  19  Human capital index (HCI) (scale 0-1)                                            602 non-null    float64
#  20  Immunization, Pol3 (% children)                                                  602 non-null    float64
#  21  Incidence of tuberculosis (per 100,000 people)                                   602 non-null    float64
#  22  Life expectancy at birth, total (years)                                          602 non-null    float64
#  23  Lifetime risk of maternal death (%)                                              602 non-null    float64
#  24  Maternal mortality ratio ( per 100,000 live births)                              602 non-null    float64
#  25  Mortality caused by road traffic injury (per 100,000 people)                     602 non-null    float64
#  26  Mortality from CVD, cancer, diabetes or CRD (%)                                  602 non-null    float64
#  27  Mortality rate, infant (per 1,000 live births)                                   602 non-null    float64
#  28  Nurses (per 1,000 people)                                                        602 non-null    float64
#  29  Out-of-pocket expenditure (% of current health expenditure)                      602 non-null    float64
#  30  Out-of-pocket expenditure per capita, PPP ($)                                    602 non-null    float64
#  31  People using drinking water services (%)                                         602 non-null    float64
#  32  Physicians (per 1,000 people)                                                    602 non-null    float64
#  33  Population                                                                       602 non-null    float64
#  34  Population growth (annual %)                                                     602 non-null    float64
#  35  Prevalence of overweight (% of adults)                                           602 non-null    float64
#  36  Prevalence of tobacco  (%)                                                       602 non-null    float64
#  37  Public spending on education (% of GDP)                                          602 non-null    float64
#  38  Rural population (%)                                                             602 non-null    float64
#  39  School enrollment, tertiary (%)                                                  602 non-null    float64
#  40  Suicide mortality rate (per 100,000)                                             602 non-null    float64
#  41  Total alcohol consumption per capita                                             602 non-null    float64
#  42  Tuberculosis death rate (per 100,000 people)                                     602 non-null    float64
#  43  Unemployment, total (%)                                                          602 non-null    float64
#  44  Year                                                                             602 non-null    float64
# dtypes: float64(43), object(2)
# memory usage: 211.8+ KB

# %%
health_rich = health[health['GDP per capita, PPP ($)']>20000]
health_rich.head()
# Out:
#   Country Name Country Code  % of adults with hypertension  \
# 0    Australia          AUS                           51.7
# 1    Australia          AUS                           52.5
# 2    Australia          AUS                           53.2
# 3    Australia          AUS                           53.7
# 4    Australia          AUS                           54.0
#
#    Birth rate (per 1,000 people)  \
# 0                           12.9
# 1                           13.2
# 2                           13.3
# 3                           13.7
# 4                           13.6
#
#    Cause of death, by communicable diseasesl and nutrition conditions (% of total)  \
# 0                                           4.569557
# 1                                           4.262027
# 2                                           4.262027
# 3                                           4.262027
# 4                                           4.262027
#
#    Cause of death, by injury (% of total)  \
# 0                                5.857025
# 1                                5.722820
# 2                                5.722820
# 3                                5.722820
# 4                                5.722820
#
#    Cause of death, by non-communicable diseases (% of total)  \
# 0                                          89.573419
# 1                                          90.015155
# 2                                          90.015155
# 3                                          90.015155
# 4                                          90.015155
#
#    Current health expenditure (% of GDP)  \
# 0                               9.327589
# 1                               9.035971
# 2                               8.761164
# 3                               8.675648
# 4                               8.541538
#
#    Current health expenditure per capita, PPP ( $)  \
# 0                                      4392.074219
# 1                                      4283.142090
# 2                                      4161.620117
# 3                                      3778.473633
# 4                                      3760.759766
#
#    Death rate (per 1,000 people)  \
# 0                            6.6
# 1                            6.6
# 2                            6.4
# 3                            6.6
# 4                            6.6
#
#    Diabetes prevalence (% of population ages 20 to 79)  \
# 0                                                6.5
# 1                                                6.5
# 2                                                6.5
# 3                                                6.5
# 4                                                6.6
#
#    Domestic general government health expenditure (% of GDP)  \
# 0                                           6.383698
# 1                                           6.100497
# 2                                           5.937055
# 3                                           6.180068
# 4                                           6.257556
#
#    Domestic general government health expenditure per capita, PPP ($)  \
# 0                                        3005.886782
# 1                                        2891.697554
# 2                                        2820.146826
# 3                                        2691.582711
# 4                                        2755.143820
#
#    Domestic private health expenditure per capita, PPP  ($)  \
# 0                                        1386.187406
# 1                                        1391.444573
# 2                                        1341.473459
# 3                                        1086.891027
# 4                                        1005.615985
#
#    Fertility rate, total (births per woman)     GDP (B$)  \
# 0                                     1.814  1076.337658
# 1                                     1.826  1046.076099
# 2                                     1.855  1022.300334
# 3                                     1.920   997.240658
# 4                                     1.926   971.956936
#
#    GDP per capita, PPP ($)  GNI per capita (US$)  \
# 0             44493.480894               60490.0
# 1             43923.258269               65180.0
# 2             43547.197484               66050.0
# 3             43118.086127               60260.0
# 4             42754.456286               50380.0
#
#    Hospital beds (per 1,000 people)  Human capital index (HCI) (scale 0-1)  \
# 0                              3.82                               0.754844
# 1                              3.79                               0.754844
# 2                              3.74                               0.754844
# 3                              3.75                               0.754844
# 4                              3.79                               0.754844
#
#    Immunization, Pol3 (% children)  \
# 0                             93.0
# 1                             92.0
# 2                             91.0
# 3                             92.0
# 4                             92.0
#
#    Incidence of tuberculosis (per 100,000 people)  \
# 0                                             6.0
# 1                                             6.5
# 2                                             6.2
# 3                                             6.6
# 4                                             6.3
#
#    Life expectancy at birth, total (years)  \
# 0                                82.400000
# 1                                82.300000
# 2                                82.148780
# 3                                82.046341
# 4                                81.895122
#
#    Lifetime risk of maternal death (%)  \
# 0                             0.012233
# 1                             0.011954
# 2                             0.011438
# 3                             0.011079
# 4                             0.011219
#
#    Maternal mortality ratio ( per 100,000 live births)  \
# 0                                                6.0
# 1                                                6.0
# 2                                                6.0
# 3                                                6.0
# 4                                                6.0
#
#    Mortality caused by road traffic injury (per 100,000 people)  \
# 0                                                5.2
# 1                                                5.4
# 2                                                5.3
# 3                                                5.8
# 4                                                5.9
#
#    Mortality from CVD, cancer, diabetes or CRD (%)  \
# 0                                              9.3
# 1                                              9.3
# 2                                              9.3
# 3                                              9.3
# 4                                              9.8
#
#    Mortality rate, infant (per 1,000 live births)  Nurses (per 1,000 people)  \
# 0                                             3.3                    12.2016
# 1                                             3.4                    12.1107
# 2                                             3.5                    11.9398
# 3                                             3.6                    10.1433
# 4                                             3.8                    10.8124
#
#    Out-of-pocket expenditure (% of current health expenditure)  \
# 0                                          18.741520
# 1                                          19.401701
# 2                                          19.504166
# 3                                          19.934338
# 4                                          19.172483
#
#    Out-of-pocket expenditure per capita, PPP ($)  \
# 0                                     823.141488
# 1                                     831.002422
# 2                                     811.689231
# 3                                     753.213764
# 4                                     721.031068
#
#    People using drinking water services (%)  Physicians (per 1,000 people)  \
# 0                                 99.970006                         3.4886
# 1                                 99.961479                         3.4314
# 2                                 99.909588                         3.3530
# 3                                 99.900767                         3.2858
# 4                                 99.891969                         3.2878
#
#    Population  Population growth (annual %)  \
# 0  24190907.0                      1.439217
# 1  23815995.0                      1.491566
# 2  23475686.0                      1.721151
# 3  23128129.0                      1.745820
# 4  22733465.0                      1.389527
#
#    Prevalence of overweight (% of adults)  Prevalence of tobacco  (%)  \
# 0                                    64.0                   15.700000
# 1                                    63.6                   18.333333
# 2                                    63.1                   18.333333
# 3                                    62.7                   18.333333
# 4                                    62.2                   18.333333
#
#    Public spending on education (% of GDP)  Rural population (%)  \
# 0                                  5.31584                14.299
# 1                                  5.16469                14.398
# 2                                  5.22924                14.498
# 3                                  4.86788                14.598
# 4                                  5.06995                14.700
#
#    School enrollment, tertiary (%)  Suicide mortality rate (per 100,000)  \
# 0                       118.610863                                  13.2
# 1                       118.610863                                  12.7
# 2                       118.610863                                  11.5
# 3                       118.610863                                  11.7
# 4                       118.610863                                  11.2
#
#    Total alcohol consumption per capita   \
# 0                              10.830000
# 1                              11.766667
# 2                              11.766667
# 3                              11.766667
# 4                              11.766667
#
#    Tuberculosis death rate (per 100,000 people)  Unemployment, total (%)  \
# 0                                          0.22                     6.05
# 1                                          0.20                     6.08
# 2                                          0.22                     5.66
# 3                                          0.16                     5.22
# 4                                          0.25                     5.08
#
#      Year
# 0  2015.0
# 1  2014.0
# 2  2013.0
# 3  2012.0
# 4  2011.0

# %%
# health['Diabetes prevalence (% of population ages 20 to 79)'].fillna(health['Diabetes prevalence (% of population ages 20 to 79)'].mean())
# health['Diabetes prevalence (% of population ages 20 to 79)']

# %%
# energy = energy[energy['gdp']>100000000000]

# %%
# energy['gdp'] = energy['gdp']/1000000000
# energy['population'] = energy['population']/1000000

# %%
# energy.rename(columns={'gdp':'gdp_B$', 'population':'pop_Million', 'greenhouse_gas_emissions':'M_Tons_C02_eq'},inplace=True) 
# energy = energy.round(0)

# %% [markdown]
# ## Check, fill or drop the missing value per country and per columns

# %%
health_rich.isna().sum()
# Out:
# Country Name                                                                       0
# Country Code                                                                       0
# % of adults with hypertension                                                      0
# Birth rate (per 1,000 people)                                                      0
# Cause of death, by communicable diseasesl and nutrition conditions (% of total)    0
# Cause of death, by injury (% of total)                                             0
# Cause of death, by non-communicable diseases (% of total)                          0
# Current health expenditure (% of GDP)                                              0
# Current health expenditure per capita, PPP ( $)                                    0
# Death rate (per 1,000 people)                                                      0
# Diabetes prevalence (% of population ages 20 to 79)                                0
# Domestic general government health expenditure (% of GDP)                          0
# Domestic general government health expenditure per capita, PPP ($)                 0
# Domestic private health expenditure per capita, PPP  ($)                           0
# Fertility rate, total (births per woman)                                           0
# GDP (B$)                                                                           0
# GDP per capita, PPP ($)                                                            0
# GNI per capita (US$)                                                               0
# Hospital beds (per 1,000 people)                                                   0
# Human capital index (HCI) (scale 0-1)                                              0
# Immunization, Pol3 (% children)                                                    0
# Incidence of tuberculosis (per 100,000 people)                                     0
# Life expectancy at birth, total (years)                                            0
# Lifetime risk of maternal death (%)                                                0
# Maternal mortality ratio ( per 100,000 live births)                                0
# Mortality caused by road traffic injury (per 100,000 people)                       0
# Mortality from CVD, cancer, diabetes or CRD (%)                                    0
# Mortality rate, infant (per 1,000 live births)                                     0
# Nurses (per 1,000 people)                                                          0
# Out-of-pocket expenditure (% of current health expenditure)                        0
# Out-of-pocket expenditure per capita, PPP ($)                                      0
# People using drinking water services (%)                                           0
# Physicians (per 1,000 people)                                                      0
# Population                                                                         0
# Population growth (annual %)                                                       0
# Prevalence of overweight (% of adults)                                             0
# Prevalence of tobacco  (%)                                                         0
# Public spending on education (% of GDP)                                            0
# Rural population (%)                                                               0
# School enrollment, tertiary (%)                                                    0
# Suicide mortality rate (per 100,000)                                               0
# Total alcohol consumption per capita                                               0
# Tuberculosis death rate (per 100,000 people)                                       0
# Unemployment, total (%)                                                            0
# Year                                                                               0
# dtype: int64

# %%
health_rich = health_rich.dropna()
health_rich.isna().sum()
# Out:
# Country Name                                                                       0
# Country Code                                                                       0
# % of adults with hypertension                                                      0
# Birth rate (per 1,000 people)                                                      0
# Cause of death, by communicable diseasesl and nutrition conditions (% of total)    0
# Cause of death, by injury (% of total)                                             0
# Cause of death, by non-communicable diseases (% of total)                          0
# Current health expenditure (% of GDP)                                              0
# Current health expenditure per capita, PPP ( $)                                    0
# Death rate (per 1,000 people)                                                      0
# Diabetes prevalence (% of population ages 20 to 79)                                0
# Domestic general government health expenditure (% of GDP)                          0
# Domestic general government health expenditure per capita, PPP ($)                 0
# Domestic private health expenditure per capita, PPP  ($)                           0
# Fertility rate, total (births per woman)                                           0
# GDP (B$)                                                                           0
# GDP per capita, PPP ($)                                                            0
# GNI per capita (US$)                                                               0
# Hospital beds (per 1,000 people)                                                   0
# Human capital index (HCI) (scale 0-1)                                              0
# Immunization, Pol3 (% children)                                                    0
# Incidence of tuberculosis (per 100,000 people)                                     0
# Life expectancy at birth, total (years)                                            0
# Lifetime risk of maternal death (%)                                                0
# Maternal mortality ratio ( per 100,000 live births)                                0
# Mortality caused by road traffic injury (per 100,000 people)                       0
# Mortality from CVD, cancer, diabetes or CRD (%)                                    0
# Mortality rate, infant (per 1,000 live births)                                     0
# Nurses (per 1,000 people)                                                          0
# Out-of-pocket expenditure (% of current health expenditure)                        0
# Out-of-pocket expenditure per capita, PPP ($)                                      0
# People using drinking water services (%)                                           0
# Physicians (per 1,000 people)                                                      0
# Population                                                                         0
# Population growth (annual %)                                                       0
# Prevalence of overweight (% of adults)                                             0
# Prevalence of tobacco  (%)                                                         0
# Public spending on education (% of GDP)                                            0
# Rural population (%)                                                               0
# School enrollment, tertiary (%)                                                    0
# Suicide mortality rate (per 100,000)                                               0
# Total alcohol consumption per capita                                               0
# Tuberculosis death rate (per 100,000 people)                                       0
# Unemployment, total (%)                                                            0
# Year                                                                               0
# dtype: int64

# %%
health_rich.shape
# Out:
# (602, 45)

# %% [markdown]
# ## New columns : New features to follow

# %%
# energy['nuclear_consumption'] = energy['nuclear_consumption'].fillna(0)
# energy['biofuel_consumption'] = energy['biofuel_consumption'].fillna(0)
# energy = energy.dropna(subset=['coal_consumption'], axis=0)

# %%
# energy['Tons_C02_per_capita']=round(energy['M_Tons_C02_eq']/energy['pop_Million'], 1)
# energy['Tons_C02_per_GDP']=round(energy['M_Tons_C02_eq']/energy['gdp_B$']*1000,1)
# energy['GDP_per_capita']=round((energy['gdp_B$']/energy['pop_Million'])*1000,1)

# %%
# energy = energy.dropna(subset=['oil_consumption'], axis=0)
# energy = energy.reset_index()
# energy

# %%
# print(energy.shape)
# print(energy.isna().sum())

# %%
# energy.loc[energy['country']== 'Asia'].head(20)

# %% [markdown]
# ### Extraction dataframe for data Viz on Tableau

# %%
# energy.to_excel("Energy_tableau.xlsx")

# %%
# energy.info()

# %% [markdown]
# # Selecting columns&rows, check correlation, train, split and run Linear model

# %% [markdown]
# ### Drop redundant rows

# %%
# energy.drop(energy[(energy['country'] == 'Asia')].index, inplace=True)
# energy.drop(energy[(energy['country'] == 'Europe')].index, inplace=True)
# energy.drop(energy[(energy['country'] == 'World')].index, inplace=True)

# %% [markdown]
# ## Distribution plots of numerical variables

# %%
# Get the numerical variables from our dataset.
numerical = health.select_dtypes(include=np.number)
numerical.head()
# Out:
#    % of adults with hypertension  Birth rate (per 1,000 people)  \
# 0                           51.7                           12.9
# 1                           52.5                           13.2
# 2                           53.2                           13.3
# 3                           53.7                           13.7
# 4                           54.0                           13.6
#
#    Cause of death, by communicable diseasesl and nutrition conditions (% of total)  \
# 0                                           4.569557
# 1                                           4.262027
# 2                                           4.262027
# 3                                           4.262027
# 4                                           4.262027
#
#    Cause of death, by injury (% of total)  \
# 0                                5.857025
# 1                                5.722820
# 2                                5.722820
# 3                                5.722820
# 4                                5.722820
#
#    Cause of death, by non-communicable diseases (% of total)  \
# 0                                          89.573419
# 1                                          90.015155
# 2                                          90.015155
# 3                                          90.015155
# 4                                          90.015155
#
#    Current health expenditure (% of GDP)  \
# 0                               9.327589
# 1                               9.035971
# 2                               8.761164
# 3                               8.675648
# 4                               8.541538
#
#    Current health expenditure per capita, PPP ( $)  \
# 0                                      4392.074219
# 1                                      4283.142090
# 2                                      4161.620117
# 3                                      3778.473633
# 4                                      3760.759766
#
#    Death rate (per 1,000 people)  \
# 0                            6.6
# 1                            6.6
# 2                            6.4
# 3                            6.6
# 4                            6.6
#
#    Diabetes prevalence (% of population ages 20 to 79)  \
# 0                                                6.5
# 1                                                6.5
# 2                                                6.5
# 3                                                6.5
# 4                                                6.6
#
#    Domestic general government health expenditure (% of GDP)  \
# 0                                           6.383698
# 1                                           6.100497
# 2                                           5.937055
# 3                                           6.180068
# 4                                           6.257556
#
#    Domestic general government health expenditure per capita, PPP ($)  \
# 0                                        3005.886782
# 1                                        2891.697554
# 2                                        2820.146826
# 3                                        2691.582711
# 4                                        2755.143820
#
#    Domestic private health expenditure per capita, PPP  ($)  \
# 0                                        1386.187406
# 1                                        1391.444573
# 2                                        1341.473459
# 3                                        1086.891027
# 4                                        1005.615985
#
#    Fertility rate, total (births per woman)     GDP (B$)  \
# 0                                     1.814  1076.337658
# 1                                     1.826  1046.076099
# 2                                     1.855  1022.300334
# 3                                     1.920   997.240658
# 4                                     1.926   971.956936
#
#    GDP per capita, PPP ($)  GNI per capita (US$)  \
# 0             44493.480894               60490.0
# 1             43923.258269               65180.0
# 2             43547.197484               66050.0
# 3             43118.086127               60260.0
# 4             42754.456286               50380.0
#
#    Hospital beds (per 1,000 people)  Human capital index (HCI) (scale 0-1)  \
# 0                              3.82                               0.754844
# 1                              3.79                               0.754844
# 2                              3.74                               0.754844
# 3                              3.75                               0.754844
# 4                              3.79                               0.754844
#
#    Immunization, Pol3 (% children)  \
# 0                             93.0
# 1                             92.0
# 2                             91.0
# 3                             92.0
# 4                             92.0
#
#    Incidence of tuberculosis (per 100,000 people)  \
# 0                                             6.0
# 1                                             6.5
# 2                                             6.2
# 3                                             6.6
# 4                                             6.3
#
#    Life expectancy at birth, total (years)  \
# 0                                82.400000
# 1                                82.300000
# 2                                82.148780
# 3                                82.046341
# 4                                81.895122
#
#    Lifetime risk of maternal death (%)  \
# 0                             0.012233
# 1                             0.011954
# 2                             0.011438
# 3                             0.011079
# 4                             0.011219
#
#    Maternal mortality ratio ( per 100,000 live births)  \
# 0                                                6.0
# 1                                                6.0
# 2                                                6.0
# 3                                                6.0
# 4                                                6.0
#
#    Mortality caused by road traffic injury (per 100,000 people)  \
# 0                                                5.2
# 1                                                5.4
# 2                                                5.3
# 3                                                5.8
# 4                                                5.9
#
#    Mortality from CVD, cancer, diabetes or CRD (%)  \
# 0                                              9.3
# 1                                              9.3
# 2                                              9.3
# 3                                              9.3
# 4                                              9.8
#
#    Mortality rate, infant (per 1,000 live births)  Nurses (per 1,000 people)  \
# 0                                             3.3                    12.2016
# 1                                             3.4                    12.1107
# 2                                             3.5                    11.9398
# 3                                             3.6                    10.1433
# 4                                             3.8                    10.8124
#
#    Out-of-pocket expenditure (% of current health expenditure)  \
# 0                                          18.741520
# 1                                          19.401701
# 2                                          19.504166
# 3                                          19.934338
# 4                                          19.172483
#
#    Out-of-pocket expenditure per capita, PPP ($)  \
# 0                                     823.141488
# 1                                     831.002422
# 2                                     811.689231
# 3                                     753.213764
# 4                                     721.031068
#
#    People using drinking water services (%)  Physicians (per 1,000 people)  \
# 0                                 99.970006                         3.4886
# 1                                 99.961479                         3.4314
# 2                                 99.909588                         3.3530
# 3                                 99.900767                         3.2858
# 4                                 99.891969                         3.2878
#
#    Population  Population growth (annual %)  \
# 0  24190907.0                      1.439217
# 1  23815995.0                      1.491566
# 2  23475686.0                      1.721151
# 3  23128129.0                      1.745820
# 4  22733465.0                      1.389527
#
#    Prevalence of overweight (% of adults)  Prevalence of tobacco  (%)  \
# 0                                    64.0                   15.700000
# 1                                    63.6                   18.333333
# 2                                    63.1                   18.333333
# 3                                    62.7                   18.333333
# 4                                    62.2                   18.333333
#
#    Public spending on education (% of GDP)  Rural population (%)  \
# 0                                  5.31584                14.299
# 1                                  5.16469                14.398
# 2                                  5.22924                14.498
# 3                                  4.86788                14.598
# 4                                  5.06995                14.700
#
#    School enrollment, tertiary (%)  Suicide mortality rate (per 100,000)  \
# 0                       118.610863                                  13.2
# 1                       118.610863                                  12.7
# 2                       118.610863                                  11.5
# 3                       118.610863                                  11.7
# 4                       118.610863                                  11.2
#
#    Total alcohol consumption per capita   \
# 0                              10.830000
# 1                              11.766667
# 2                              11.766667
# 3                              11.766667
# 4                              11.766667
#
#    Tuberculosis death rate (per 100,000 people)  Unemployment, total (%)  \
# 0                                          0.22                     6.05
# 1                                          0.20                     6.08
# 2                                          0.22                     5.66
# 3                                          0.16                     5.22
# 4                                          0.25                     5.08
#
#      Year
# 0  2015.0
# 1  2014.0
# 2  2013.0
# 3  2012.0
# 4  2011.0

# %%
# Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.
for column in numerical:
    sns.distplot(numerical[column])
    plt.show()
# Out:
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Selection minimum relevant columns for analysis : only consumption of each energy

# %%
# energy.drop(energy.columns.difference(['M_Tons_C02_eq', 'wind_consumption', 'solar_consumption', 'other_renewable_consumption', 'coal_consumption', 'oil_consumption', 'gas_consumption']), 1, inplace=True)
# energy.head()

# %% [markdown]
# ## Heatmap to check correlation, (output : 'Life expectancy at birth')

# %%
num = health_rich.select_dtypes("number")
display(num.head())

cf = 0.5

columns = []
corr_matrix = num.corr()

for col in num.columns:
        if (abs(corr_matrix.loc[col,'Life expectancy at birth, total (years)']) >= cf):
            columns.append(col)
numerical_trimmed = pd.DataFrame(num, columns=columns)
pd.set_option('display.max_columns', None)
corr_matrix2 = numerical_trimmed.corr()
sns.set(rc={'figure.figsize':(15,8)})
sns.heatmap(corr_matrix2, annot=True)
plt.show()

numerical_trimmed = numerical_trimmed.drop(["Human capital index (HCI) (scale 0-1)", "Current health expenditure per capita, PPP ( $)", "Domestic general government health expenditure (% of GDP)","GNI per capita (US$)", "Lifetime risk of maternal death (%)", "Tuberculosis death rate (per 100,000 people)"], axis = 1)
corr_matrix2 = numerical_trimmed.corr()
sns.set(rc={'figure.figsize':(15,8)})
sns.heatmap(corr_matrix2, annot=True)
plt.show()

### Concatenate cat and num

# numerical_trimmed = pd.concat([numerical_trimmed, cat], axis = 1)
numerical_trimmed.shape
# Out:
#    % of adults with hypertension  Birth rate (per 1,000 people)  \
# 0                           51.7                           12.9
# 1                           52.5                           13.2
# 2                           53.2                           13.3
# 3                           53.7                           13.7
# 4                           54.0                           13.6
#
#    Cause of death, by communicable diseasesl and nutrition conditions (% of total)  \
# 0                                           4.569557
# 1                                           4.262027
# 2                                           4.262027
# 3                                           4.262027
# 4                                           4.262027
#
#    Cause of death, by injury (% of total)  \
# 0                                5.857025
# 1                                5.722820
# 2                                5.722820
# 3                                5.722820
# 4                                5.722820
#
#    Cause of death, by non-communicable diseases (% of total)  \
# 0                                          89.573419
# 1                                          90.015155
# 2                                          90.015155
# 3                                          90.015155
# 4                                          90.015155
#
#    Current health expenditure (% of GDP)  \
# 0                               9.327589
# 1                               9.035971
# 2                               8.761164
# 3                               8.675648
# 4                               8.541538
#
#    Current health expenditure per capita, PPP ( $)  \
# 0                                      4392.074219
# 1                                      4283.142090
# 2                                      4161.620117
# 3                                      3778.473633
# 4                                      3760.759766
#
#    Death rate (per 1,000 people)  \
# 0                            6.6
# 1                            6.6
# 2                            6.4
# 3                            6.6
# 4                            6.6
#
#    Diabetes prevalence (% of population ages 20 to 79)  \
# 0                                                6.5
# 1                                                6.5
# 2                                                6.5
# 3                                                6.5
# 4                                                6.6
#
#    Domestic general government health expenditure (% of GDP)  \
# 0                                           6.383698
# 1                                           6.100497
# 2                                           5.937055
# 3                                           6.180068
# 4                                           6.257556
#
#    Domestic general government health expenditure per capita, PPP ($)  \
# 0                                        3005.886782
# 1                                        2891.697554
# 2                                        2820.146826
# 3                                        2691.582711
# 4                                        2755.143820
#
#    Domestic private health expenditure per capita, PPP  ($)  \
# 0                                        1386.187406
# 1                                        1391.444573
# 2                                        1341.473459
# 3                                        1086.891027
# 4                                        1005.615985
#
#    Fertility rate, total (births per woman)     GDP (B$)  \
# 0                                     1.814  1076.337658
# 1                                     1.826  1046.076099
# 2                                     1.855  1022.300334
# 3                                     1.920   997.240658
# 4                                     1.926   971.956936
#
#    GDP per capita, PPP ($)  GNI per capita (US$)  \
# 0             44493.480894               60490.0
# 1             43923.258269               65180.0
# 2             43547.197484               66050.0
# 3             43118.086127               60260.0
# 4             42754.456286               50380.0
#
#    Hospital beds (per 1,000 people)  Human capital index (HCI) (scale 0-1)  \
# 0                              3.82                               0.754844
# 1                              3.79                               0.754844
# 2                              3.74                               0.754844
# 3                              3.75                               0.754844
# 4                              3.79                               0.754844
#
#    Immunization, Pol3 (% children)  \
# 0                             93.0
# 1                             92.0
# 2                             91.0
# 3                             92.0
# 4                             92.0
#
#    Incidence of tuberculosis (per 100,000 people)  \
# 0                                             6.0
# 1                                             6.5
# 2                                             6.2
# 3                                             6.6
# 4                                             6.3
#
#    Life expectancy at birth, total (years)  \
# 0                                82.400000
# 1                                82.300000
# 2                                82.148780
# 3                                82.046341
# 4                                81.895122
#
#    Lifetime risk of maternal death (%)  \
# 0                             0.012233
# 1                             0.011954
# 2                             0.011438
# 3                             0.011079
# 4                             0.011219
#
#    Maternal mortality ratio ( per 100,000 live births)  \
# 0                                                6.0
# 1                                                6.0
# 2                                                6.0
# 3                                                6.0
# 4                                                6.0
#
#    Mortality caused by road traffic injury (per 100,000 people)  \
# 0                                                5.2
# 1                                                5.4
# 2                                                5.3
# 3                                                5.8
# 4                                                5.9
#
#    Mortality from CVD, cancer, diabetes or CRD (%)  \
# 0                                              9.3
# 1                                              9.3
# 2                                              9.3
# 3                                              9.3
# 4                                              9.8
#
#    Mortality rate, infant (per 1,000 live births)  Nurses (per 1,000 people)  \
# 0                                             3.3                    12.2016
# 1                                             3.4                    12.1107
# 2                                             3.5                    11.9398
# 3                                             3.6                    10.1433
# 4                                             3.8                    10.8124
#
#    Out-of-pocket expenditure (% of current health expenditure)  \
# 0                                          18.741520
# 1                                          19.401701
# 2                                          19.504166
# 3                                          19.934338
# 4                                          19.172483
#
#    Out-of-pocket expenditure per capita, PPP ($)  \
# 0                                     823.141488
# 1                                     831.002422
# 2                                     811.689231
# 3                                     753.213764
# 4                                     721.031068
#
#    People using drinking water services (%)  Physicians (per 1,000 people)  \
# 0                                 99.970006                         3.4886
# 1                                 99.961479                         3.4314
# 2                                 99.909588                         3.3530
# 3                                 99.900767                         3.2858
# 4                                 99.891969                         3.2878
#
#    Population  Population growth (annual %)  \
# 0  24190907.0                      1.439217
# 1  23815995.0                      1.491566
# 2  23475686.0                      1.721151
# 3  23128129.0                      1.745820
# 4  22733465.0                      1.389527
#
#    Prevalence of overweight (% of adults)  Prevalence of tobacco  (%)  \
# 0                                    64.0                   15.700000
# 1                                    63.6                   18.333333
# 2                                    63.1                   18.333333
# 3                                    62.7                   18.333333
# 4                                    62.2                   18.333333
#
#    Public spending on education (% of GDP)  Rural population (%)  \
# 0                                  5.31584                14.299
# 1                                  5.16469                14.398
# 2                                  5.22924                14.498
# 3                                  4.86788                14.598
# 4                                  5.06995                14.700
#
#    School enrollment, tertiary (%)  Suicide mortality rate (per 100,000)  \
# 0                       118.610863                                  13.2
# 1                       118.610863                                  12.7
# 2                       118.610863                                  11.5
# 3                       118.610863                                  11.7
# 4                       118.610863                                  11.2
#
#    Total alcohol consumption per capita   \
# 0                              10.830000
# 1                              11.766667
# 2                              11.766667
# 3                              11.766667
# 4                              11.766667
#
#    Tuberculosis death rate (per 100,000 people)  Unemployment, total (%)  \
# 0                                          0.22                     6.05
# 1                                          0.20                     6.08
# 2                                          0.22                     5.66
# 3                                          0.16                     5.22
# 4                                          0.25                     5.08
#
#      Year
# 0  2015.0
# 1  2014.0
# 2  2013.0
# 3  2012.0
# 4  2011.0
# (602, 9)

# %% [markdown]
# ## We keep 9 columns out of 15
# #### 1 Output to predict : Life expectancy at birth (years)
# ####  8 Features : those which has highest correlation to output and the lowest to each other to minimize the Noise & Overfitting

# %%
health2 =numerical_trimmed
health2.head()
# Out:
#    Current health expenditure (% of GDP)  \
# 0                               9.327589
# 1                               9.035971
# 2                               8.761164
# 3                               8.675648
# 4                               8.541538
#
#    Domestic general government health expenditure per capita, PPP ($)  \
# 0                                        3005.886782
# 1                                        2891.697554
# 2                                        2820.146826
# 3                                        2691.582711
# 4                                        2755.143820
#
#    Incidence of tuberculosis (per 100,000 people)  \
# 0                                             6.0
# 1                                             6.5
# 2                                             6.2
# 3                                             6.6
# 4                                             6.3
#
#    Life expectancy at birth, total (years)  \
# 0                                82.400000
# 1                                82.300000
# 2                                82.148780
# 3                                82.046341
# 4                                81.895122
#
#    Maternal mortality ratio ( per 100,000 live births)  \
# 0                                                6.0
# 1                                                6.0
# 2                                                6.0
# 3                                                6.0
# 4                                                6.0
#
#    Mortality caused by road traffic injury (per 100,000 people)  \
# 0                                                5.2
# 1                                                5.4
# 2                                                5.3
# 3                                                5.8
# 4                                                5.9
#
#    Mortality from CVD, cancer, diabetes or CRD (%)  \
# 0                                              9.3
# 1                                              9.3
# 2                                              9.3
# 3                                              9.3
# 4                                              9.8
#
#    Mortality rate, infant (per 1,000 live births)  \
# 0                                             3.3
# 1                                             3.4
# 2                                             3.5
# 3                                             3.6
# 4                                             3.8
#
#    Out-of-pocket expenditure per capita, PPP ($)
# 0                                     823.141488
# 1                                     831.002422
# 2                                     811.689231
# 3                                     753.213764
# 4                                     721.031068

# %% [markdown]
# ## Train/test/split data

# %%
### X,y split

y = health2["Life expectancy at birth, total (years)"]
x = health2.drop(["Life expectancy at birth, total (years)"], axis = 1)

# %%
### Train-test split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 80)
print(x_train.shape)
print(x_test.shape)
# Out:
# (421, 8)
# (181, 8)

# %% [markdown]
# ## Scaling & transformation

# %%
### Normaliyation by columns 

transformer = MinMaxScaler().fit(x_train)
x_train_norm = transformer.transform(x_train)
x_train_norm = pd.DataFrame(x_train_norm, columns=x_train.columns)
x_train_norm
# Out:
#      Current health expenditure (% of GDP)  \
# 0                                 0.606539
# 1                                 0.425364
# 2                                 0.124116
# 3                                 0.455417
# 4                                 0.489681
# ..                                     ...
# 416                               0.482871
# 417                               0.426844
# 418                               0.384848
# 419                               0.463929
# 420                               0.641354
#
#      Domestic general government health expenditure per capita, PPP ($)  \
# 0                                             0.573841
# 1                                             0.285037
# 2                                             0.172973
# 3                                             0.266450
# 4                                             0.427654
# ..                                                 ...
# 416                                           0.478913
# 417                                           0.277119
# 418                                           0.142539
# 419                                           0.251446
# 420                                           0.699149
#
#      Incidence of tuberculosis (per 100,000 people)  \
# 0                                          0.126761
# 1                                          0.047183
# 2                                          0.105634
# 3                                          0.050704
# 4                                          0.026761
# ..                                              ...
# 416                                        0.032394
# 417                                        0.070423
# 418                                        0.091549
# 419                                        0.030986
# 420                                        0.027465
#
#      Maternal mortality ratio ( per 100,000 live births)  \
# 0                                                0.100
# 1                                                0.025
# 2                                                0.500
# 3                                                0.225
# 4                                                0.000
# ..                                                 ...
# 416                                              0.100
# 417                                              0.150
# 418                                              0.275
# 419                                              0.025
# 420                                              0.075
#
#      Mortality caused by road traffic injury (per 100,000 people)  \
# 0                                             0.081081
# 1                                             0.285285
# 2                                             0.708709
# 3                                             0.240240
# 4                                             0.105105
# ..                                                 ...
# 416                                           0.105105
# 417                                           0.264264
# 418                                           0.243243
# 419                                           0.414414
# 420                                           0.063063
#
#      Mortality from CVD, cancer, diabetes or CRD (%)  \
# 0                                           0.034602
# 1                                           0.148789
# 2                                           0.602076
# 3                                           0.169550
# 4                                           0.055363
# ..                                               ...
# 416                                         0.031142
# 417                                         0.200692
# 418                                         0.584775
# 419                                         0.190311
# 420                                         0.152249
#
#      Mortality rate, infant (per 1,000 live births)  \
# 0                                          0.024540
# 1                                          0.134969
# 2                                          0.754601
# 3                                          0.220859
# 4                                          0.073620
# ..                                              ...
# 416                                        0.104294
# 417                                        0.061350
# 418                                        0.202454
# 419                                        0.104294
# 420                                        0.085890
#
#      Out-of-pocket expenditure per capita, PPP ($)
# 0                                         0.230894
# 1                                         0.257288
# 2                                         0.104017
# 3                                         0.122177
# 4                                         0.351763
# ..                                             ...
# 416                                       0.372955
# 417                                       0.120376
# 418                                       0.174226
# 419                                       0.422297
# 420                                       0.321306
#
# [421 rows x 8 columns]

# %%
transformer = MinMaxScaler().fit(x_test)
x_test_norm = transformer.transform(x_test)
x_test_norm = pd.DataFrame(x_test_norm, columns=x_test.columns)
x_test_norm
# Out:
#      Current health expenditure (% of GDP)  \
# 0                                 0.280020
# 1                                 0.333335
# 2                                 0.503511
# 3                                 0.071538
# 4                                 0.302393
# ..                                     ...
# 176                               0.424932
# 177                               0.497521
# 178                               0.303067
# 179                               0.508825
# 180                               0.506238
#
#      Domestic general government health expenditure per capita, PPP ($)  \
# 0                                             0.101107
# 1                                             0.247781
# 2                                             0.508112
# 3                                             0.121570
# 4                                             0.164919
# ..                                                 ...
# 176                                           0.386295
# 177                                           0.469822
# 178                                           0.158434
# 179                                           0.219834
# 180                                           0.268303
#
#      Incidence of tuberculosis (per 100,000 people)  \
# 0                                          0.018048
# 1                                          0.027406
# 2                                          0.028743
# 3                                          0.104278
# 4                                          0.057487
# ..                                              ...
# 176                                        0.020722
# 177                                        0.075153
# 178                                        0.064171
# 179                                        0.217914
# 180                                        0.137701
#
#      Maternal mortality ratio ( per 100,000 live births)  \
# 0                                             0.250000
# 1                                             0.142857
# 2                                             0.214286
# 3                                             0.642857
# 4                                             0.107143
# ..                                                 ...
# 176                                           0.107143
# 177                                           0.280612
# 178                                           0.107143
# 179                                           0.250000
# 180                                           0.250000
#
#      Mortality caused by road traffic injury (per 100,000 people)  \
# 0                                             0.236686
# 1                                             0.136095
# 2                                             0.085799
# 3                                             0.707101
# 4                                             0.328402
# ..                                                 ...
# 176                                           0.112426
# 177                                           0.092139
# 178                                           0.357988
# 179                                           0.423077
# 180                                           0.192308
#
#      Mortality from CVD, cancer, diabetes or CRD (%)  \
# 0                                           0.097276
# 1                                           0.342412
# 2                                           0.167315
# 3                                           0.680934
# 4                                           0.428016
# ..                                               ...
# 176                                         0.128405
# 177                                         0.171206
# 178                                         0.455253
# 179                                         0.186770
# 180                                         0.108949
#
#      Mortality rate, infant (per 1,000 live births)  \
# 0                                          0.071429
# 1                                          0.181319
# 2                                          0.120879
# 3                                          0.554945
# 4                                          0.098901
# ..                                              ...
# 176                                        0.071429
# 177                                        0.155416
# 178                                        0.104396
# 179                                        0.087912
# 180                                        0.065934
#
#      Out-of-pocket expenditure per capita, PPP ($)
# 0                                         0.587420
# 1                                         0.160265
# 2                                         0.192110
# 3                                         0.115228
# 4                                         0.029378
# ..                                             ...
# 176                                       0.204228
# 177                                       0.230736
# 178                                       0.021389
# 179                                       0.288007
# 180                                       0.422662
#
# [181 rows x 8 columns]

# %% [markdown]
# ## Apply the linear model & results

# %%
lm = LinearRegression()
lm.fit(x_train_norm, y_train)
y_pred_train = lm.predict(x_train_norm)
y_pred_test = lm.predict(x_test_norm)
y_pred_train = lm.predict(x_train_norm)
y_pred_test = lm.predict(x_test_norm)
r2_train = r2_score(y_pred_train, y_train)
r2_test = r2_score(y_pred_test, y_test)
mse_train = mean_squared_error(y_pred_train, y_train)
mse_test = mean_squared_error(y_pred_test, y_test)
mae_train = mean_absolute_error(y_pred_train, y_train)
mae_test = mean_absolute_error(y_pred_test, y_test)
mape_train = mean_absolute_percentage_error(y_pred_train, y_train)
mape_test = mean_absolute_percentage_error(y_pred_test, y_test)


print('\nResult model with split in ', '70/30')
print("R2 score of trained dataset is", round(r2_train,3))
print("R2 score of test dataset is", round(r2_test,3))

print("Mean absolute percentage error of train dataset is", round(mape_train, 2))
print("Mean absolute percentage error of test dataset is", round(mape_test, 2))
# Out:
# Result model with split in  70/30
# R2 score of trained dataset is 0.836
# R2 score of test dataset is 0.809
# Mean absolute percentage error of train dataset is 0.01
# Mean absolute percentage error of test dataset is 0.01
#
#
#  Which feature impact the life expectancy?
# [('Mortality from CVD, cancer, diabetes or CRD (%)', -11.0),
#  ('Incidence of tuberculosis (per 100,000 people)', -3.0),
#  ('Out-of-pocket expenditure per capita, PPP ($)', 2.0),
#  ('Domestic general government health expenditure per capita, PPP ($)', 2.0),
#  ('Mortality rate, infant (per 1,000 live births)', -2.0),
#  ('Current health expenditure (% of GDP)', -1.0),
#  ('Maternal mortality ratio ( per 100,000 live births)', -1.0),
#  ('Mortality caused by road traffic injury (per 100,000 people)', -1.0)]

# %% [markdown]
# ## Apply DecisionTreeRegressor & Results

# %%
from sklearn.tree import DecisionTreeRegressor
regr = DecisionTreeRegressor(max_depth=10,
                             min_samples_split=10,
                             min_samples_leaf =5,
                             random_state = 42)
regr.fit(x_train, y_train)
print("Train data R2 was: {:.2f}".format(regr.score(x_train, y_train)))
print("Test data R2 was: {:.2f}".format(regr.score(x_test, y_test)))
# Out:
# Train data R2 was: 0.98
# Test data R2 was: 0.93

# %% [markdown]
# ## Apply KNeighborsRegressor & Results

# %%
from sklearn.neighbors import KNeighborsRegressor
regr = KNeighborsRegressor(n_neighbors=3)
regr.fit(x_train, y_train)
print("Train data R2 was: {:.2f}".format(regr.score(x_train, y_train)))
print("Test data R2 was: {:.2f}".format(regr.score(x_test, y_test)))
# Out:
# Train data R2 was: 0.83
# Test data R2 was: 0.68

# %% [markdown]
# # Hyperparameter search

# %% [markdown]
# ## Apply RandomForestRegressor + GridSearchCV & Result

# %%
from sklearn.model_selection import GridSearchCV

max_depth_choices= [6,8,10,12,14]
criterion_choices = ['squared_error','absolute_error'] 
min_samples_split_choices = [6,8,10,12,14] 
min_samples_leaf_choices = [4,5,6,7,8] 
# Create the  grid 
grid = {'max_depth': max_depth_choices,
        'criterion': criterion_choices,
        'min_samples_split': min_samples_split_choices,
        'min_samples_leaf': min_samples_leaf_choices}
# Instantiate the grid search model object
model = RandomForestRegressor()
grid_search = GridSearchCV(estimator = model, param_grid = grid, cv = 5)
# Fit the grid search to the data
grid_search.fit(x_train, y_train)
grid_search.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 10,
#  'min_samples_leaf': 4,
#  'min_samples_split': 8}

# %% [markdown]
# ### More detailed search : optimization parameters

# %%
max_depth_choices= [11,12,13]
criterion_choices = ['squared_error','absolute_error'] 
min_samples_split_choices = [7,8,9] 
min_samples_leaf_choices = [3,4,5] 
# Create the  grid 
grid = {'max_depth': max_depth_choices,
        'criterion': criterion_choices,
        'min_samples_split': min_samples_split_choices,
        'min_samples_leaf': min_samples_leaf_choices}
# Instantiate the grid search model object
model = RandomForestRegressor()
grid_search = GridSearchCV(estimator = model, param_grid = grid, cv = 5)
# Fit the grid search to the data
grid_search.fit(x_train, y_train)
grid_search.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 13,
#  'min_samples_leaf': 3,
#  'min_samples_split': 7}

# %% [markdown]
# ## Apply RandomForestRegressor model & Results

# %%
from sklearn.ensemble import RandomForestRegressor

clf = RandomForestRegressor(max_depth=13,
                             min_samples_split = 7,
                             min_samples_leaf =3,
                             max_samples=.9,
                             random_state = 42)
clf.fit(x_train_norm, y_train)

print("The R2 for the Random Forest in the TRAIN set is {:.2f}".format(clf.score(x_train_norm, y_train)))
print("The R2 for the Random Forest in the TEST  set is {:.2f}".format(clf.score(x_test_norm, y_test)))

y_pred = clf.predict(x_test_norm)
y_pred = clf.predict(x_test_norm)
print('\n\n Which feature impact the life expectancy?')
column_relevance = list(zip(np.abs(lm.coef_), x_train_norm.columns, np.round_(lm.coef_)))
column_relevance.sort(reverse=True)
column_relevance = [(item[1],item[-1]) for item in column_relevance]
column_relevance
# Out:
# The R2 for the Random Forest in the TRAIN set is 0.98
# The R2 for the Random Forest in the TEST  set is 0.95
#
#
#  Which feature impact the life expectancy?
# [('Mortality from CVD, cancer, diabetes or CRD (%)', -11.0),
#  ('Incidence of tuberculosis (per 100,000 people)', -3.0),
#  ('Out-of-pocket expenditure per capita, PPP ($)', 2.0),
#  ('Domestic general government health expenditure per capita, PPP ($)', 2.0),
#  ('Mortality rate, infant (per 1,000 live births)', -2.0),
#  ('Current health expenditure (% of GDP)', -1.0),
#  ('Maternal mortality ratio ( per 100,000 live births)', -1.0),
#  ('Mortality caused by road traffic injury (per 100,000 people)', -1.0)]

# %% [markdown]
# ## Apply RandomForestClassifier + cross_val_score & Result

# %%
from sklearn.model_selection import cross_val_score

y_true = y_train
clf = RandomForestRegressor(max_depth=13,
                             min_samples_split = 7,
                             min_samples_leaf =3,
                             max_samples=.9,
                             random_state = 42)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)

cross_val_scores = cross_val_score(clf, x_train, y_train, cv=5)

print("The mean R2 of the folds was {:.2f}".format(np.mean(cross_val_scores)))
# Out:
# The mean R2 of the folds was 0.93

# %% [markdown]
# ## RandomizedSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV

max_depth_choices= [6,8,10,12,14]
criterion_choices = ['squared_error','absolute_error'] 
min_samples_split_choices = [6,8,10,12,14] 
min_samples_leaf_choices = [4,5,6,7,8] 
# Create the  grid 
random_grid = {'max_depth': max_depth_choices,
        'criterion': criterion_choices,
        'min_samples_split': min_samples_split_choices,
        'min_samples_leaf': min_samples_leaf_choices}
# Instantiate the grid search model object
model = RandomForestRegressor()
random_search = RandomizedSearchCV(estimator = model, param_distributions = random_grid, n_iter=25, cv = 5, n_jobs = 10) 
random_search.fit(x_train, y_train)
random_search.best_params_
# Out:
# {'min_samples_split': 8,
#  'min_samples_leaf': 4,
#  'max_depth': 14,
#  'criterion': 'squared_error'}
