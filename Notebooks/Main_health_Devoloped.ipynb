# %% [markdown]
# ## Import libraries

# %%
# Base libraries
import pandas as pd
import numpy as np
from pyforest import *

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# sklearn
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# ## Exploring the database

# %%
# Open the excel database 
# In Row the 184 countries and the years
health = pd.read_excel('C:/Users/igrav/Desktop/ironhack/Lecture/Week_9/Project/data_origine/World bank/Data_Health_Source4.xlsx')
pd.set_option('display.max_columns', None)
health.head()
# Out:
#   Country Name Country Code  Year  Birth rate (per 1,000 people)  \
# 0  Afghanistan          AFG  2021                      38.900842
# 1  Afghanistan          AFG  2012                      37.690000
# 2  Afghanistan          AFG  2011                      38.750000
# 3  Afghanistan          AFG  2013                      36.670000
# 4  Afghanistan          AFG  2016                      33.981000
#
#    Cause of death, by communicable diseasesl and nutrition conditions (% of total)  \
# 0                                          40.157115
# 1                                          40.157115
# 2                                          40.157115
# 3                                          40.157115
# 4                                          40.157115
#
#    Cause of death, by injury (% of total)  \
# 0                               14.903117
# 1                               14.903117
# 2                               14.903117
# 3                               14.903117
# 4                               14.903117
#
#    Cause of death, by non-communicable diseases (% of total)  \
# 0                                          44.939767
# 1                                          44.939767
# 2                                          44.939767
# 3                                          44.939767
# 4                                          44.939767
#
#    Current health expenditure (% of GDP)  \
# 0                              10.223393
# 1                               7.897176
# 2                               8.561907
# 3                               8.805941
# 4                              11.818562
#
#    Current health expenditure per capita, PPP ( $)  \
# 0                                       163.917681
# 1                                       151.917984
# 2                                       143.091522
# 3                                       174.059479
# 4                                       234.140213
#
#    Death rate (per 1,000 people)  \
# 0                       8.211684
# 1                       7.645000
# 2                       7.936000
# 3                       7.380000
# 4                       6.742000
#
#    Diabetes prevalence (% of population ages 20 to 79)  \
# 0                                              10.90
# 1                                               9.25
# 2                                               7.60
# 3                                               9.25
# 4                                               9.25
#
#    Domestic general government health expenditure (% of GDP)  \
# 0                                           0.535133
# 1                                           0.342887
# 2                                           0.480000
# 3                                           0.443358
# 4                                           0.600128
#
#    Domestic general government health expenditure per capita, PPP ($)  \
# 0                                           8.692245
# 1                                           6.596119
# 2                                           8.022033
# 3                                           8.763480
# 4                                          11.889279
#
#    Domestic private health expenditure per capita, PPP  ($)  \
# 0                                         125.905373
# 1                                         113.157953
# 2                                         104.821934
# 3                                         125.406128
# 4                                         177.886491
#
#    External health expenditure per capita, PPP ($)  \
# 0                                        29.320065
# 1                                        32.163919
# 2                                        30.247552
# 3                                        39.889862
# 4                                        44.364468
#
#    Fertility rate, total (births per woman)  GNI per capita (US$)  \
# 0                                  5.755316                 550.0
# 1                                  5.562000                 630.0
# 2                                  5.770000                 530.0
# 3                                  5.359000                 650.0
# 4                                  4.800000                 550.0
#
#    Hospital beds (per 1,000 people)  Human capital index (HCI) (scale 0-1)  \
# 0                          0.443125                               0.394258
# 1                          0.530000                               0.394258
# 2                          0.440000                               0.394258
# 3                          0.530000                               0.394258
# 4                          0.500000                               0.394258
#
#    Immunization, measles second dose (% of children)  \
# 0                                               30.0
# 1                                               33.0
# 2                                               31.0
# 3                                               38.0
# 4                                               40.0
#
#    Immunization, Pol3 (% children)  Incidence of HIV  (per 1,000  population)  \
# 0                        62.894737                                   0.028421
# 1                        67.000000                                   0.030000
# 2                        68.000000                                   0.030000
# 3                        64.000000                                   0.030000
# 4                        71.000000                                   0.040000
#
#    Incidence of tuberculosis (per 100,000 people)  \
# 0                                      189.210526
# 1                                      189.000000
# 2                                      189.000000
# 3                                      189.000000
# 4                                      189.000000
#
#    Life expectancy at birth, total (years)  \
# 0                                61.295789
# 1                                62.054000
# 2                                61.553000
# 3                                62.525000
# 4                                63.763000
#
#    Lifetime risk of maternal death (%)  \
# 0                             6.144000
# 1                             5.023027
# 2                             5.520806
# 3                             4.538151
# 4                             3.330914
#
#    Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                          37.266041
# 1                                          34.357446
# 2                                          31.448851
# 3                                          34.357446
# 4                                          34.357446
#
#    Maternal mortality ratio ( per 100,000 live births)  \
# 0                                            963.625
# 1                                            858.000
# 2                                            905.000
# 3                                            810.000
# 4                                            673.000
#
#    Mortality caused by road traffic injury (per 100,000 people)  \
# 0                                          14.705556
# 1                                          13.800000
# 2                                          14.200000
# 3                                          14.000000
# 4                                          14.800000
#
#    Mortality from CVD, cancer, diabetes or CRD (%)  \
# 0                                        38.061111
# 1                                        36.600000
# 2                                        37.100000
# 3                                        36.200000
# 4                                        35.600000
#
#    Mortality rate, infant (per 1,000 live births)  Nurses (per 1,000 people)  \
# 0                                       63.105263                     0.3563
# 1                                       59.500000                     0.3563
# 2                                       61.800000                     0.3563
# 3                                       57.300000                     0.2495
# 4                                       51.300000                     0.1482
#
#    Out-of-pocket expenditure (% of current health expenditure)  \
# 0                                          77.517930
# 1                                          74.486206
# 2                                          73.255173
# 3                                          72.047867
# 4                                          75.974335
#
#    Out-of-pocket expenditure per capita, PPP ($)  \
# 0                                     125.873408
# 1                                     113.157953
# 2                                     104.821934
# 3                                     125.406128
# 4                                     177.886491
#
#    People using drinking water services (%)  Physicians (per 1,000 people)  \
# 0                                 51.484575                       0.236064
# 1                                 53.403517                       0.241400
# 2                                 50.827846                       0.251800
# 3                                 56.014043                       0.284600
# 4                                 64.054883                       0.278200
#
#    Population growth (annual %)  GDP per capita, PPP ($)  Population  \
# 0                      2.303412              6457.050021   3051010.0
# 1                      3.407600              1848.700026  32269592.0
# 2                      3.143106              1839.273579  31161378.0
# 3                      3.494592              1838.960244  33370804.0
# 4                      2.778035              1829.565008  36296111.0
#
#     GDP (B$)  Prevalence of anemia among children (%)  \
# 0  19.700524                                44.644444
# 1  59.656796                                43.500000
# 2  57.314299                                43.500000
# 3  61.367582                                43.500000
# 4   0.000000                                43.900000
#
#    Prevalence of tobacco  (%)  Prevalence of HIV (%)  \
# 0                       26.45                    0.1
# 1                       26.45                    0.1
# 2                       26.45                    0.1
# 3                       26.45                    0.1
# 4                       26.45                    0.1
#
#    Prevalence of overweight (% of adults)  \
# 0                               18.873333
# 1                               20.500000
# 2                               19.900000
# 3                               21.100000
# 4                               23.000000
#
#    Prevalence of overweight ( % of children )  \
# 0                                    5.184211
# 1                                    5.300000
# 2                                    5.500000
# 3                                    5.200000
# 4                                    4.600000
#
#    Public spending on education (% of GDP)  Rural population (%)  \
# 0                                  3.30172                73.686
# 1                                  3.32000                75.840
# 2                                  3.46201                76.052
# 3                                  3.45446                75.627
# 4                                  3.51198                74.980
#
#    School enrollment, tertiary (%)  Suicide mortality rate (per 100,000)  \
# 0                         5.709476                              4.405556
# 1                         7.397240                              4.000000
# 2                         3.622260                              4.100000
# 3                         5.709476                              4.000000
# 4                         5.709476                              4.000000
#
#    Total alcohol consumption per capita   % of adults with hypertension  \
# 0                                   0.21                          38.45
# 1                                   0.21                          40.20
# 2                                   0.21                          39.40
# 3                                   0.21                          41.00
# 4                                   0.21                          43.40
#
#    Tuberculosis death rate (per 100,000 people)  Unemployment, total (%)
# 0                                     41.105263                   13.283
# 1                                     44.000000                   11.341
# 2                                     44.000000                   11.054
# 3                                     43.000000                   11.193
# 4                                     34.000000                   11.158

# %%
health.shape
# Out:
# (2606, 52)

# %% [markdown]
# ## Pivot and Melt

# %%
# years = [i for i in np.arange(2002,2022,1)]

# %%
# health.melt(health, id_vars=['Country_Name'], value_vars=[(years)])

# %%
health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2606 entries, 0 to 2605
# Data columns (total 52 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   Country Name                                                                     2606 non-null   object
#  1   Country Code                                                                     2606 non-null   object
#  2   Year                                                                             2606 non-null   int64
#  3   Birth rate (per 1,000 people)                                                    2606 non-null   float64
#  4   Cause of death, by communicable diseasesl and nutrition conditions (% of total)  2606 non-null   float64
#  5   Cause of death, by injury (% of total)                                           2606 non-null   float64
#  6   Cause of death, by non-communicable diseases (% of total)                        2606 non-null   float64
#  7   Current health expenditure (% of GDP)                                            2606 non-null   float64
#  8   Current health expenditure per capita, PPP ( $)                                  2606 non-null   float64
#  9   Death rate (per 1,000 people)                                                    2606 non-null   float64
#  10  Diabetes prevalence (% of population ages 20 to 79)                              2587 non-null   float64
#  11  Domestic general government health expenditure (% of GDP)                        2606 non-null   float64
#  12  Domestic general government health expenditure per capita, PPP ($)               2606 non-null   float64
#  13  Domestic private health expenditure per capita, PPP  ($)                         2606 non-null   float64
#  14  External health expenditure per capita, PPP ($)                                  2587 non-null   float64
#  15  Fertility rate, total (births per woman)                                         2606 non-null   float64
#  16  GNI per capita (US$)                                                             2606 non-null   float64
#  17  Hospital beds (per 1,000 people)                                                 2486 non-null   float64
#  18  Human capital index (HCI) (scale 0-1)                                            2116 non-null   float64
#  19  Immunization, measles second dose (% of children)                                2103 non-null   float64
#  20  Immunization, Pol3 (% children)                                                  2342 non-null   float64
#  21  Incidence of HIV  (per 1,000  population)                                        2169 non-null   float64
#  22  Incidence of tuberculosis (per 100,000 people)                                   2507 non-null   float64
#  23  Life expectancy at birth, total (years)                                          2606 non-null   float64
#  24  Lifetime risk of maternal death (%)                                              2606 non-null   float64
#  25  Literacy rate, adult total (% of people ages 15 and above)                       2416 non-null   float64
#  26  Maternal mortality ratio ( per 100,000 live births)                              2606 non-null   float64
#  27  Mortality caused by road traffic injury (per 100,000 people)                     2606 non-null   float64
#  28  Mortality from CVD, cancer, diabetes or CRD (%)                                  2606 non-null   float64
#  29  Mortality rate, infant (per 1,000 live births)                                   2606 non-null   float64
#  30  Nurses (per 1,000 people)                                                        2581 non-null   float64
#  31  Out-of-pocket expenditure (% of current health expenditure)                      2606 non-null   float64
#  32  Out-of-pocket expenditure per capita, PPP ($)                                    2606 non-null   float64
#  33  People using drinking water services (%)                                         2606 non-null   float64
#  34  Physicians (per 1,000 people)                                                    2575 non-null   float64
#  35  Population growth (annual %)                                                     2606 non-null   float64
#  36  GDP per capita, PPP ($)                                                          2606 non-null   float64
#  37  Population                                                                       2606 non-null   float64
#  38  GDP (B$)                                                                         2606 non-null   float64
#  39  Prevalence of anemia among children (%)                                          2586 non-null   float64
#  40  Prevalence of tobacco  (%)                                                       2292 non-null   float64
#  41  Prevalence of HIV (%)                                                            2149 non-null   float64
#  42  Prevalence of overweight (% of adults)                                           2567 non-null   float64
#  43  Prevalence of overweight ( % of children )                                       2508 non-null   float64
#  44  Public spending on education (% of GDP)                                          2540 non-null   float64
#  45  Rural population (%)                                                             2606 non-null   float64
#  46  School enrollment, tertiary (%)                                                  2449 non-null   float64
#  47  Suicide mortality rate (per 100,000)                                             2606 non-null   float64
#  48  Total alcohol consumption per capita                                             2587 non-null   float64
#  49  % of adults with hypertension                                                    2606 non-null   float64
#  50  Tuberculosis death rate (per 100,000 people)                                     2507 non-null   float64
#  51  Unemployment, total (%)                                                          2565 non-null   float64
# dtypes: float64(49), int64(1), object(2)
# memory usage: 1.0+ MB

# %%
health = health.apply(lambda x : x.replace("..", np.nan))
health.head()
# Out:
#   Country Name Country Code  Year  Birth rate (per 1,000 people)  \
# 0  Afghanistan          AFG  2021                      38.900842
# 1  Afghanistan          AFG  2012                      37.690000
# 2  Afghanistan          AFG  2011                      38.750000
# 3  Afghanistan          AFG  2013                      36.670000
# 4  Afghanistan          AFG  2016                      33.981000
#
#    Cause of death, by communicable diseasesl and nutrition conditions (% of total)  \
# 0                                          40.157115
# 1                                          40.157115
# 2                                          40.157115
# 3                                          40.157115
# 4                                          40.157115
#
#    Cause of death, by injury (% of total)  \
# 0                               14.903117
# 1                               14.903117
# 2                               14.903117
# 3                               14.903117
# 4                               14.903117
#
#    Cause of death, by non-communicable diseases (% of total)  \
# 0                                          44.939767
# 1                                          44.939767
# 2                                          44.939767
# 3                                          44.939767
# 4                                          44.939767
#
#    Current health expenditure (% of GDP)  \
# 0                              10.223393
# 1                               7.897176
# 2                               8.561907
# 3                               8.805941
# 4                              11.818562
#
#    Current health expenditure per capita, PPP ( $)  \
# 0                                       163.917681
# 1                                       151.917984
# 2                                       143.091522
# 3                                       174.059479
# 4                                       234.140213
#
#    Death rate (per 1,000 people)  \
# 0                       8.211684
# 1                       7.645000
# 2                       7.936000
# 3                       7.380000
# 4                       6.742000
#
#    Diabetes prevalence (% of population ages 20 to 79)  \
# 0                                              10.90
# 1                                               9.25
# 2                                               7.60
# 3                                               9.25
# 4                                               9.25
#
#    Domestic general government health expenditure (% of GDP)  \
# 0                                           0.535133
# 1                                           0.342887
# 2                                           0.480000
# 3                                           0.443358
# 4                                           0.600128
#
#    Domestic general government health expenditure per capita, PPP ($)  \
# 0                                           8.692245
# 1                                           6.596119
# 2                                           8.022033
# 3                                           8.763480
# 4                                          11.889279
#
#    Domestic private health expenditure per capita, PPP  ($)  \
# 0                                         125.905373
# 1                                         113.157953
# 2                                         104.821934
# 3                                         125.406128
# 4                                         177.886491
#
#    External health expenditure per capita, PPP ($)  \
# 0                                        29.320065
# 1                                        32.163919
# 2                                        30.247552
# 3                                        39.889862
# 4                                        44.364468
#
#    Fertility rate, total (births per woman)  GNI per capita (US$)  \
# 0                                  5.755316                 550.0
# 1                                  5.562000                 630.0
# 2                                  5.770000                 530.0
# 3                                  5.359000                 650.0
# 4                                  4.800000                 550.0
#
#    Hospital beds (per 1,000 people)  Human capital index (HCI) (scale 0-1)  \
# 0                          0.443125                               0.394258
# 1                          0.530000                               0.394258
# 2                          0.440000                               0.394258
# 3                          0.530000                               0.394258
# 4                          0.500000                               0.394258
#
#    Immunization, measles second dose (% of children)  \
# 0                                               30.0
# 1                                               33.0
# 2                                               31.0
# 3                                               38.0
# 4                                               40.0
#
#    Immunization, Pol3 (% children)  Incidence of HIV  (per 1,000  population)  \
# 0                        62.894737                                   0.028421
# 1                        67.000000                                   0.030000
# 2                        68.000000                                   0.030000
# 3                        64.000000                                   0.030000
# 4                        71.000000                                   0.040000
#
#    Incidence of tuberculosis (per 100,000 people)  \
# 0                                      189.210526
# 1                                      189.000000
# 2                                      189.000000
# 3                                      189.000000
# 4                                      189.000000
#
#    Life expectancy at birth, total (years)  \
# 0                                61.295789
# 1                                62.054000
# 2                                61.553000
# 3                                62.525000
# 4                                63.763000
#
#    Lifetime risk of maternal death (%)  \
# 0                             6.144000
# 1                             5.023027
# 2                             5.520806
# 3                             4.538151
# 4                             3.330914
#
#    Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                          37.266041
# 1                                          34.357446
# 2                                          31.448851
# 3                                          34.357446
# 4                                          34.357446
#
#    Maternal mortality ratio ( per 100,000 live births)  \
# 0                                            963.625
# 1                                            858.000
# 2                                            905.000
# 3                                            810.000
# 4                                            673.000
#
#    Mortality caused by road traffic injury (per 100,000 people)  \
# 0                                          14.705556
# 1                                          13.800000
# 2                                          14.200000
# 3                                          14.000000
# 4                                          14.800000
#
#    Mortality from CVD, cancer, diabetes or CRD (%)  \
# 0                                        38.061111
# 1                                        36.600000
# 2                                        37.100000
# 3                                        36.200000
# 4                                        35.600000
#
#    Mortality rate, infant (per 1,000 live births)  Nurses (per 1,000 people)  \
# 0                                       63.105263                     0.3563
# 1                                       59.500000                     0.3563
# 2                                       61.800000                     0.3563
# 3                                       57.300000                     0.2495
# 4                                       51.300000                     0.1482
#
#    Out-of-pocket expenditure (% of current health expenditure)  \
# 0                                          77.517930
# 1                                          74.486206
# 2                                          73.255173
# 3                                          72.047867
# 4                                          75.974335
#
#    Out-of-pocket expenditure per capita, PPP ($)  \
# 0                                     125.873408
# 1                                     113.157953
# 2                                     104.821934
# 3                                     125.406128
# 4                                     177.886491
#
#    People using drinking water services (%)  Physicians (per 1,000 people)  \
# 0                                 51.484575                       0.236064
# 1                                 53.403517                       0.241400
# 2                                 50.827846                       0.251800
# 3                                 56.014043                       0.284600
# 4                                 64.054883                       0.278200
#
#    Population growth (annual %)  GDP per capita, PPP ($)  Population  \
# 0                      2.303412              6457.050021   3051010.0
# 1                      3.407600              1848.700026  32269592.0
# 2                      3.143106              1839.273579  31161378.0
# 3                      3.494592              1838.960244  33370804.0
# 4                      2.778035              1829.565008  36296111.0
#
#     GDP (B$)  Prevalence of anemia among children (%)  \
# 0  19.700524                                44.644444
# 1  59.656796                                43.500000
# 2  57.314299                                43.500000
# 3  61.367582                                43.500000
# 4   0.000000                                43.900000
#
#    Prevalence of tobacco  (%)  Prevalence of HIV (%)  \
# 0                       26.45                    0.1
# 1                       26.45                    0.1
# 2                       26.45                    0.1
# 3                       26.45                    0.1
# 4                       26.45                    0.1
#
#    Prevalence of overweight (% of adults)  \
# 0                               18.873333
# 1                               20.500000
# 2                               19.900000
# 3                               21.100000
# 4                               23.000000
#
#    Prevalence of overweight ( % of children )  \
# 0                                    5.184211
# 1                                    5.300000
# 2                                    5.500000
# 3                                    5.200000
# 4                                    4.600000
#
#    Public spending on education (% of GDP)  Rural population (%)  \
# 0                                  3.30172                73.686
# 1                                  3.32000                75.840
# 2                                  3.46201                76.052
# 3                                  3.45446                75.627
# 4                                  3.51198                74.980
#
#    School enrollment, tertiary (%)  Suicide mortality rate (per 100,000)  \
# 0                         5.709476                              4.405556
# 1                         7.397240                              4.000000
# 2                         3.622260                              4.100000
# 3                         5.709476                              4.000000
# 4                         5.709476                              4.000000
#
#    Total alcohol consumption per capita   % of adults with hypertension  \
# 0                                   0.21                          38.45
# 1                                   0.21                          40.20
# 2                                   0.21                          39.40
# 3                                   0.21                          41.00
# 4                                   0.21                          43.40
#
#    Tuberculosis death rate (per 100,000 people)  Unemployment, total (%)
# 0                                     41.105263                   13.283
# 1                                     44.000000                   11.341
# 2                                     44.000000                   11.054
# 3                                     43.000000                   11.193
# 4                                     34.000000                   11.158

# %%
health.isna().sum()/len(health)
# Out:
# Country Name                                                                       0.000000
# Country Code                                                                       0.000000
# Year                                                                               0.000000
# Birth rate (per 1,000 people)                                                      0.000000
# Cause of death, by communicable diseasesl and nutrition conditions (% of total)    0.000000
# Cause of death, by injury (% of total)                                             0.000000
# Cause of death, by non-communicable diseases (% of total)                          0.000000
# Current health expenditure (% of GDP)                                              0.000000
# Current health expenditure per capita, PPP ( $)                                    0.000000
# Death rate (per 1,000 people)                                                      0.000000
# Diabetes prevalence (% of population ages 20 to 79)                                0.007291
# Domestic general government health expenditure (% of GDP)                          0.000000
# Domestic general government health expenditure per capita, PPP ($)                 0.000000
# Domestic private health expenditure per capita, PPP  ($)                           0.000000
# External health expenditure per capita, PPP ($)                                    0.007291
# Fertility rate, total (births per woman)                                           0.000000
# GNI per capita (US$)                                                               0.000000
# Hospital beds (per 1,000 people)                                                   0.046048
# Human capital index (HCI) (scale 0-1)                                              0.188028
# Immunization, measles second dose (% of children)                                  0.193016
# Immunization, Pol3 (% children)                                                    0.101305
# Incidence of HIV  (per 1,000  population)                                          0.167690
# Incidence of tuberculosis (per 100,000 people)                                     0.037989
# Life expectancy at birth, total (years)                                            0.000000
# Lifetime risk of maternal death (%)                                                0.000000
# Literacy rate, adult total (% of people ages 15 and above)                         0.072909
# Maternal mortality ratio ( per 100,000 live births)                                0.000000
# Mortality caused by road traffic injury (per 100,000 people)                       0.000000
# Mortality from CVD, cancer, diabetes or CRD (%)                                    0.000000
# Mortality rate, infant (per 1,000 live births)                                     0.000000
# Nurses (per 1,000 people)                                                          0.009593
# Out-of-pocket expenditure (% of current health expenditure)                        0.000000
# Out-of-pocket expenditure per capita, PPP ($)                                      0.000000
# People using drinking water services (%)                                           0.000000
# Physicians (per 1,000 people)                                                      0.011896
# Population growth (annual %)                                                       0.000000
# GDP per capita, PPP ($)                                                            0.000000
# Population                                                                         0.000000
# GDP (B$)                                                                           0.000000
# Prevalence of anemia among children (%)                                            0.007675
# Prevalence of tobacco  (%)                                                         0.120491
# Prevalence of HIV (%)                                                              0.175365
# Prevalence of overweight (% of adults)                                             0.014965
# Prevalence of overweight ( % of children )                                         0.037606
# Public spending on education (% of GDP)                                            0.025326
# Rural population (%)                                                               0.000000
# School enrollment, tertiary (%)                                                    0.060246
# Suicide mortality rate (per 100,000)                                               0.000000
# Total alcohol consumption per capita                                               0.007291
# % of adults with hypertension                                                      0.000000
# Tuberculosis death rate (per 100,000 people)                                       0.037989
# Unemployment, total (%)                                                            0.015733
# dtype: float64

# %% [markdown]
# ## Drop the unrelevant columns

# %%
# energy.drop(energy.columns.difference(['country', 'iso_code', 'year',  'population', 'gdp', 'greenhouse_gas_emissions', 'electricity_demand', ' primary_energy_consumption', ' renewables_consumption', ' carbon_intensity_elec', 'low_carbon_consumption', 'fossil_fuel_consumption', 'hydro_consumption', 'biofuel_consumption', 'wind_consumption', 'solar_consumption', 'nuclear_consumption', 'other_renewable_consumption', 'coal_consumption', 'oil_consumption', 'gas_consumption']), 1, inplace=True)
# energy2 = energy[energy.columns.difference(['gdp', 'population'])]

# %%
health.shape
# Out:
# (2606, 52)

# %%
health['Life expectancy at birth, total (years)'].describe()
# Out:
# count    2606.000000
# mean       66.442634
# std         8.337322
# min        41.376000
# 25%        60.672000
# 50%        68.205386
# 75%        73.056895
# max        84.615610
# Name: Life expectancy at birth, total (years), dtype: float64

# %% [markdown]
# ## Rename & Create relevant new columns for further analysis (C02 per cap, ...)

# %%
health_features = health[health.columns.difference(['Country Name', 'Country Code'])].astype('float')
health_country = health[['Country Name', 'Country Code']]
health = pd.concat([health_country,health_features], axis=1)
health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2606 entries, 0 to 2605
# Data columns (total 52 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   Country Name                                                                     2606 non-null   object
#  1   Country Code                                                                     2606 non-null   object
#  2   % of adults with hypertension                                                    2606 non-null   float64
#  3   Birth rate (per 1,000 people)                                                    2606 non-null   float64
#  4   Cause of death, by communicable diseasesl and nutrition conditions (% of total)  2606 non-null   float64
#  5   Cause of death, by injury (% of total)                                           2606 non-null   float64
#  6   Cause of death, by non-communicable diseases (% of total)                        2606 non-null   float64
#  7   Current health expenditure (% of GDP)                                            2606 non-null   float64
#  8   Current health expenditure per capita, PPP ( $)                                  2606 non-null   float64
#  9   Death rate (per 1,000 people)                                                    2606 non-null   float64
#  10  Diabetes prevalence (% of population ages 20 to 79)                              2587 non-null   float64
#  11  Domestic general government health expenditure (% of GDP)                        2606 non-null   float64
#  12  Domestic general government health expenditure per capita, PPP ($)               2606 non-null   float64
#  13  Domestic private health expenditure per capita, PPP  ($)                         2606 non-null   float64
#  14  External health expenditure per capita, PPP ($)                                  2587 non-null   float64
#  15  Fertility rate, total (births per woman)                                         2606 non-null   float64
#  16  GDP (B$)                                                                         2606 non-null   float64
#  17  GDP per capita, PPP ($)                                                          2606 non-null   float64
#  18  GNI per capita (US$)                                                             2606 non-null   float64
#  19  Hospital beds (per 1,000 people)                                                 2486 non-null   float64
#  20  Human capital index (HCI) (scale 0-1)                                            2116 non-null   float64
#  21  Immunization, Pol3 (% children)                                                  2342 non-null   float64
#  22  Immunization, measles second dose (% of children)                                2103 non-null   float64
#  23  Incidence of HIV  (per 1,000  population)                                        2169 non-null   float64
#  24  Incidence of tuberculosis (per 100,000 people)                                   2507 non-null   float64
#  25  Life expectancy at birth, total (years)                                          2606 non-null   float64
#  26  Lifetime risk of maternal death (%)                                              2606 non-null   float64
#  27  Literacy rate, adult total (% of people ages 15 and above)                       2416 non-null   float64
#  28  Maternal mortality ratio ( per 100,000 live births)                              2606 non-null   float64
#  29  Mortality caused by road traffic injury (per 100,000 people)                     2606 non-null   float64
#  30  Mortality from CVD, cancer, diabetes or CRD (%)                                  2606 non-null   float64
#  31  Mortality rate, infant (per 1,000 live births)                                   2606 non-null   float64
#  32  Nurses (per 1,000 people)                                                        2581 non-null   float64
#  33  Out-of-pocket expenditure (% of current health expenditure)                      2606 non-null   float64
#  34  Out-of-pocket expenditure per capita, PPP ($)                                    2606 non-null   float64
#  35  People using drinking water services (%)                                         2606 non-null   float64
#  36  Physicians (per 1,000 people)                                                    2575 non-null   float64
#  37  Population                                                                       2606 non-null   float64
#  38  Population growth (annual %)                                                     2606 non-null   float64
#  39  Prevalence of HIV (%)                                                            2149 non-null   float64
#  40  Prevalence of anemia among children (%)                                          2586 non-null   float64
#  41  Prevalence of overweight ( % of children )                                       2508 non-null   float64
#  42  Prevalence of overweight (% of adults)                                           2567 non-null   float64
#  43  Prevalence of tobacco  (%)                                                       2292 non-null   float64
#  44  Public spending on education (% of GDP)                                          2540 non-null   float64
#  45  Rural population (%)                                                             2606 non-null   float64
#  46  School enrollment, tertiary (%)                                                  2449 non-null   float64
#  47  Suicide mortality rate (per 100,000)                                             2606 non-null   float64
#  48  Total alcohol consumption per capita                                             2587 non-null   float64
#  49  Tuberculosis death rate (per 100,000 people)                                     2507 non-null   float64
#  50  Unemployment, total (%)                                                          2565 non-null   float64
#  51  Year                                                                             2606 non-null   float64
# dtypes: float64(50), object(2)
# memory usage: 1.0+ MB

# %%
# health_rich = health[health['GDP per capita, PPP ($)']>20000]
# health_rich.head()

# %%
# health['Diabetes prevalence (% of population ages 20 to 79)'].fillna(health['Diabetes prevalence (% of population ages 20 to 79)'].mean())
# health['Diabetes prevalence (% of population ages 20 to 79)']

# %%
# energy = energy[energy['gdp']>100000000000]

# %%
# energy['gdp'] = energy['gdp']/1000000000
# energy['population'] = energy['population']/1000000

# %%
# energy.rename(columns={'gdp':'gdp_B$', 'population':'pop_Million', 'greenhouse_gas_emissions':'M_Tons_C02_eq'},inplace=True) 
# energy = energy.round(0)

# %% [markdown]
# ## Check, fill or drop the missing value per country and per columns

# %%
health.isna().sum()
# Out:
# Country Name                                                                         0
# Country Code                                                                         0
# % of adults with hypertension                                                        0
# Birth rate (per 1,000 people)                                                        0
# Cause of death, by communicable diseasesl and nutrition conditions (% of total)      0
# Cause of death, by injury (% of total)                                               0
# Cause of death, by non-communicable diseases (% of total)                            0
# Current health expenditure (% of GDP)                                                0
# Current health expenditure per capita, PPP ( $)                                      0
# Death rate (per 1,000 people)                                                        0
# Diabetes prevalence (% of population ages 20 to 79)                                 19
# Domestic general government health expenditure (% of GDP)                            0
# Domestic general government health expenditure per capita, PPP ($)                   0
# Domestic private health expenditure per capita, PPP  ($)                             0
# External health expenditure per capita, PPP ($)                                     19
# Fertility rate, total (births per woman)                                             0
# GDP (B$)                                                                             0
# GDP per capita, PPP ($)                                                              0
# GNI per capita (US$)                                                                 0
# Hospital beds (per 1,000 people)                                                   120
# Human capital index (HCI) (scale 0-1)                                              490
# Immunization, Pol3 (% children)                                                    264
# Immunization, measles second dose (% of children)                                  503
# Incidence of HIV  (per 1,000  population)                                          437
# Incidence of tuberculosis (per 100,000 people)                                      99
# Life expectancy at birth, total (years)                                              0
# Lifetime risk of maternal death (%)                                                  0
# Literacy rate, adult total (% of people ages 15 and above)                         190
# Maternal mortality ratio ( per 100,000 live births)                                  0
# Mortality caused by road traffic injury (per 100,000 people)                         0
# Mortality from CVD, cancer, diabetes or CRD (%)                                      0
# Mortality rate, infant (per 1,000 live births)                                       0
# Nurses (per 1,000 people)                                                           25
# Out-of-pocket expenditure (% of current health expenditure)                          0
# Out-of-pocket expenditure per capita, PPP ($)                                        0
# People using drinking water services (%)                                             0
# Physicians (per 1,000 people)                                                       31
# Population                                                                           0
# Population growth (annual %)                                                         0
# Prevalence of HIV (%)                                                              457
# Prevalence of anemia among children (%)                                             20
# Prevalence of overweight ( % of children )                                          98
# Prevalence of overweight (% of adults)                                              39
# Prevalence of tobacco  (%)                                                         314
# Public spending on education (% of GDP)                                             66
# Rural population (%)                                                                 0
# School enrollment, tertiary (%)                                                    157
# Suicide mortality rate (per 100,000)                                                 0
# Total alcohol consumption per capita                                                19
# Tuberculosis death rate (per 100,000 people)                                        99
# Unemployment, total (%)                                                             41
# Year                                                                                 0
# dtype: int64

# %%
health = health.dropna()
health.isna().sum()
# Out:
# Country Name                                                                       0
# Country Code                                                                       0
# % of adults with hypertension                                                      0
# Birth rate (per 1,000 people)                                                      0
# Cause of death, by communicable diseasesl and nutrition conditions (% of total)    0
# Cause of death, by injury (% of total)                                             0
# Cause of death, by non-communicable diseases (% of total)                          0
# Current health expenditure (% of GDP)                                              0
# Current health expenditure per capita, PPP ( $)                                    0
# Death rate (per 1,000 people)                                                      0
# Diabetes prevalence (% of population ages 20 to 79)                                0
# Domestic general government health expenditure (% of GDP)                          0
# Domestic general government health expenditure per capita, PPP ($)                 0
# Domestic private health expenditure per capita, PPP  ($)                           0
# External health expenditure per capita, PPP ($)                                    0
# Fertility rate, total (births per woman)                                           0
# GDP (B$)                                                                           0
# GDP per capita, PPP ($)                                                            0
# GNI per capita (US$)                                                               0
# Hospital beds (per 1,000 people)                                                   0
# Human capital index (HCI) (scale 0-1)                                              0
# Immunization, Pol3 (% children)                                                    0
# Immunization, measles second dose (% of children)                                  0
# Incidence of HIV  (per 1,000  population)                                          0
# Incidence of tuberculosis (per 100,000 people)                                     0
# Life expectancy at birth, total (years)                                            0
# Lifetime risk of maternal death (%)                                                0
# Literacy rate, adult total (% of people ages 15 and above)                         0
# Maternal mortality ratio ( per 100,000 live births)                                0
# Mortality caused by road traffic injury (per 100,000 people)                       0
# Mortality from CVD, cancer, diabetes or CRD (%)                                    0
# Mortality rate, infant (per 1,000 live births)                                     0
# Nurses (per 1,000 people)                                                          0
# Out-of-pocket expenditure (% of current health expenditure)                        0
# Out-of-pocket expenditure per capita, PPP ($)                                      0
# People using drinking water services (%)                                           0
# Physicians (per 1,000 people)                                                      0
# Population                                                                         0
# Population growth (annual %)                                                       0
# Prevalence of HIV (%)                                                              0
# Prevalence of anemia among children (%)                                            0
# Prevalence of overweight ( % of children )                                         0
# Prevalence of overweight (% of adults)                                             0
# Prevalence of tobacco  (%)                                                         0
# Public spending on education (% of GDP)                                            0
# Rural population (%)                                                               0
# School enrollment, tertiary (%)                                                    0
# Suicide mortality rate (per 100,000)                                               0
# Total alcohol consumption per capita                                               0
# Tuberculosis death rate (per 100,000 people)                                       0
# Unemployment, total (%)                                                            0
# Year                                                                               0
# dtype: int64

# %%
health.shape
# Out:
# (1306, 52)

# %% [markdown]
# ## New columns : New features to follow

# %%
# energy['nuclear_consumption'] = energy['nuclear_consumption'].fillna(0)
# energy['biofuel_consumption'] = energy['biofuel_consumption'].fillna(0)
# energy = energy.dropna(subset=['coal_consumption'], axis=0)

# %%
# energy['Tons_C02_per_capita']=round(energy['M_Tons_C02_eq']/energy['pop_Million'], 1)
# energy['Tons_C02_per_GDP']=round(energy['M_Tons_C02_eq']/energy['gdp_B$']*1000,1)
# energy['GDP_per_capita']=round((energy['gdp_B$']/energy['pop_Million'])*1000,1)

# %%
# energy = energy.dropna(subset=['oil_consumption'], axis=0)
# energy = energy.reset_index()
# energy

# %%
# print(energy.shape)
# print(energy.isna().sum())

# %%
# energy.loc[energy['country']== 'Asia'].head(20)

# %% [markdown]
# ### Extraction dataframe for data Viz on Tableau

# %%
# energy.to_excel("Energy_tableau.xlsx")

# %%
# energy.info()

# %% [markdown]
# # Selecting columns&rows, check correlation, train, split and run Linear model

# %% [markdown]
# ### Drop redundant rows

# %%
# energy.drop(energy[(energy['country'] == 'Asia')].index, inplace=True)
# energy.drop(energy[(energy['country'] == 'Europe')].index, inplace=True)
# energy.drop(energy[(energy['country'] == 'World')].index, inplace=True)

# %% [markdown]
# ## Distribution plots of numerical variables

# %%
# Get the numerical variables from our dataset.
numerical = health.select_dtypes(include=np.number)
numerical.head()
# Out:
#    % of adults with hypertension  Birth rate (per 1,000 people)  \
# 0                          38.45                      38.900842
# 1                          40.20                      37.690000
# 2                          39.40                      38.750000
# 3                          41.00                      36.670000
# 4                          43.40                      33.981000
#
#    Cause of death, by communicable diseasesl and nutrition conditions (% of total)  \
# 0                                          40.157115
# 1                                          40.157115
# 2                                          40.157115
# 3                                          40.157115
# 4                                          40.157115
#
#    Cause of death, by injury (% of total)  \
# 0                               14.903117
# 1                               14.903117
# 2                               14.903117
# 3                               14.903117
# 4                               14.903117
#
#    Cause of death, by non-communicable diseases (% of total)  \
# 0                                          44.939767
# 1                                          44.939767
# 2                                          44.939767
# 3                                          44.939767
# 4                                          44.939767
#
#    Current health expenditure (% of GDP)  \
# 0                              10.223393
# 1                               7.897176
# 2                               8.561907
# 3                               8.805941
# 4                              11.818562
#
#    Current health expenditure per capita, PPP ( $)  \
# 0                                       163.917681
# 1                                       151.917984
# 2                                       143.091522
# 3                                       174.059479
# 4                                       234.140213
#
#    Death rate (per 1,000 people)  \
# 0                       8.211684
# 1                       7.645000
# 2                       7.936000
# 3                       7.380000
# 4                       6.742000
#
#    Diabetes prevalence (% of population ages 20 to 79)  \
# 0                                              10.90
# 1                                               9.25
# 2                                               7.60
# 3                                               9.25
# 4                                               9.25
#
#    Domestic general government health expenditure (% of GDP)  \
# 0                                           0.535133
# 1                                           0.342887
# 2                                           0.480000
# 3                                           0.443358
# 4                                           0.600128
#
#    Domestic general government health expenditure per capita, PPP ($)  \
# 0                                           8.692245
# 1                                           6.596119
# 2                                           8.022033
# 3                                           8.763480
# 4                                          11.889279
#
#    Domestic private health expenditure per capita, PPP  ($)  \
# 0                                         125.905373
# 1                                         113.157953
# 2                                         104.821934
# 3                                         125.406128
# 4                                         177.886491
#
#    External health expenditure per capita, PPP ($)  \
# 0                                        29.320065
# 1                                        32.163919
# 2                                        30.247552
# 3                                        39.889862
# 4                                        44.364468
#
#    Fertility rate, total (births per woman)   GDP (B$)  \
# 0                                  5.755316  19.700524
# 1                                  5.562000  59.656796
# 2                                  5.770000  57.314299
# 3                                  5.359000  61.367582
# 4                                  4.800000   0.000000
#
#    GDP per capita, PPP ($)  GNI per capita (US$)  \
# 0              6457.050021                 550.0
# 1              1848.700026                 630.0
# 2              1839.273579                 530.0
# 3              1838.960244                 650.0
# 4              1829.565008                 550.0
#
#    Hospital beds (per 1,000 people)  Human capital index (HCI) (scale 0-1)  \
# 0                          0.443125                               0.394258
# 1                          0.530000                               0.394258
# 2                          0.440000                               0.394258
# 3                          0.530000                               0.394258
# 4                          0.500000                               0.394258
#
#    Immunization, Pol3 (% children)  \
# 0                        62.894737
# 1                        67.000000
# 2                        68.000000
# 3                        64.000000
# 4                        71.000000
#
#    Immunization, measles second dose (% of children)  \
# 0                                               30.0
# 1                                               33.0
# 2                                               31.0
# 3                                               38.0
# 4                                               40.0
#
#    Incidence of HIV  (per 1,000  population)  \
# 0                                   0.028421
# 1                                   0.030000
# 2                                   0.030000
# 3                                   0.030000
# 4                                   0.040000
#
#    Incidence of tuberculosis (per 100,000 people)  \
# 0                                      189.210526
# 1                                      189.000000
# 2                                      189.000000
# 3                                      189.000000
# 4                                      189.000000
#
#    Life expectancy at birth, total (years)  \
# 0                                61.295789
# 1                                62.054000
# 2                                61.553000
# 3                                62.525000
# 4                                63.763000
#
#    Lifetime risk of maternal death (%)  \
# 0                             6.144000
# 1                             5.023027
# 2                             5.520806
# 3                             4.538151
# 4                             3.330914
#
#    Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                          37.266041
# 1                                          34.357446
# 2                                          31.448851
# 3                                          34.357446
# 4                                          34.357446
#
#    Maternal mortality ratio ( per 100,000 live births)  \
# 0                                            963.625
# 1                                            858.000
# 2                                            905.000
# 3                                            810.000
# 4                                            673.000
#
#    Mortality caused by road traffic injury (per 100,000 people)  \
# 0                                          14.705556
# 1                                          13.800000
# 2                                          14.200000
# 3                                          14.000000
# 4                                          14.800000
#
#    Mortality from CVD, cancer, diabetes or CRD (%)  \
# 0                                        38.061111
# 1                                        36.600000
# 2                                        37.100000
# 3                                        36.200000
# 4                                        35.600000
#
#    Mortality rate, infant (per 1,000 live births)  Nurses (per 1,000 people)  \
# 0                                       63.105263                     0.3563
# 1                                       59.500000                     0.3563
# 2                                       61.800000                     0.3563
# 3                                       57.300000                     0.2495
# 4                                       51.300000                     0.1482
#
#    Out-of-pocket expenditure (% of current health expenditure)  \
# 0                                          77.517930
# 1                                          74.486206
# 2                                          73.255173
# 3                                          72.047867
# 4                                          75.974335
#
#    Out-of-pocket expenditure per capita, PPP ($)  \
# 0                                     125.873408
# 1                                     113.157953
# 2                                     104.821934
# 3                                     125.406128
# 4                                     177.886491
#
#    People using drinking water services (%)  Physicians (per 1,000 people)  \
# 0                                 51.484575                       0.236064
# 1                                 53.403517                       0.241400
# 2                                 50.827846                       0.251800
# 3                                 56.014043                       0.284600
# 4                                 64.054883                       0.278200
#
#    Population  Population growth (annual %)  Prevalence of HIV (%)  \
# 0   3051010.0                      2.303412                    0.1
# 1  32269592.0                      3.407600                    0.1
# 2  31161378.0                      3.143106                    0.1
# 3  33370804.0                      3.494592                    0.1
# 4  36296111.0                      2.778035                    0.1
#
#    Prevalence of anemia among children (%)  \
# 0                                44.644444
# 1                                43.500000
# 2                                43.500000
# 3                                43.500000
# 4                                43.900000
#
#    Prevalence of overweight ( % of children )  \
# 0                                    5.184211
# 1                                    5.300000
# 2                                    5.500000
# 3                                    5.200000
# 4                                    4.600000
#
#    Prevalence of overweight (% of adults)  Prevalence of tobacco  (%)  \
# 0                               18.873333                       26.45
# 1                               20.500000                       26.45
# 2                               19.900000                       26.45
# 3                               21.100000                       26.45
# 4                               23.000000                       26.45
#
#    Public spending on education (% of GDP)  Rural population (%)  \
# 0                                  3.30172                73.686
# 1                                  3.32000                75.840
# 2                                  3.46201                76.052
# 3                                  3.45446                75.627
# 4                                  3.51198                74.980
#
#    School enrollment, tertiary (%)  Suicide mortality rate (per 100,000)  \
# 0                         5.709476                              4.405556
# 1                         7.397240                              4.000000
# 2                         3.622260                              4.100000
# 3                         5.709476                              4.000000
# 4                         5.709476                              4.000000
#
#    Total alcohol consumption per capita   \
# 0                                   0.21
# 1                                   0.21
# 2                                   0.21
# 3                                   0.21
# 4                                   0.21
#
#    Tuberculosis death rate (per 100,000 people)  Unemployment, total (%)  \
# 0                                     41.105263                   13.283
# 1                                     44.000000                   11.341
# 2                                     44.000000                   11.054
# 3                                     43.000000                   11.193
# 4                                     34.000000                   11.158
#
#      Year
# 0  2021.0
# 1  2012.0
# 2  2011.0
# 3  2013.0
# 4  2016.0

# %%
# Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.
for column in numerical:
    sns.distplot(numerical[column])
    plt.show()
# Out:
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\igrav\anaconda3\envs\energy_project1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Selection minimum relevant columns for analysis : only consumption of each energy

# %%
# energy.drop(energy.columns.difference(['M_Tons_C02_eq', 'wind_consumption', 'solar_consumption', 'other_renewable_consumption', 'coal_consumption', 'oil_consumption', 'gas_consumption']), 1, inplace=True)
# energy.head()

# %% [markdown]
# ## Heatmap to check correlation, (output : 'Life expectancy at birth')

# %%
num = health.select_dtypes("number")
display(num.head())

cf = 0.6

columns = []
corr_matrix = num.corr()

for col in num.columns:
        if (abs(corr_matrix.loc[col,'Life expectancy at birth, total (years)']) >= cf):
            columns.append(col)
numerical_trimmed = pd.DataFrame(num, columns=columns)
pd.set_option('display.max_columns', None)
corr_matrix2 = numerical_trimmed.corr()
sns.set(rc={'figure.figsize':(15,8)})
sns.heatmap(corr_matrix2, annot=True)
plt.show()

numerical_trimmed = numerical_trimmed.drop(['Tuberculosis death rate (per 100,000 people)',"Death rate (per 1,000 people)", "Prevalence of HIV (%)","Lifetime risk of maternal death (%)","% of adults with hypertension", "GDP per capita, PPP ($)", "Birth rate (per 1,000 people)", "People using drinking water services (%)", "Cause of death, by non-communicable diseases (% of total)","Human capital index (HCI) (scale 0-1)"], axis = 1)
corr_matrix2 = numerical_trimmed.corr()
sns.set(rc={'figure.figsize':(15,8)})
sns.heatmap(corr_matrix2, annot=True)
plt.show()

### Concatenate cat and num

# numerical_trimmed = pd.concat([numerical_trimmed, cat], axis = 1)
numerical_trimmed.shape
# Out:
#    % of adults with hypertension  Birth rate (per 1,000 people)  \
# 0                          38.45                      38.900842
# 1                          40.20                      37.690000
# 2                          39.40                      38.750000
# 3                          41.00                      36.670000
# 4                          43.40                      33.981000
#
#    Cause of death, by communicable diseasesl and nutrition conditions (% of total)  \
# 0                                          40.157115
# 1                                          40.157115
# 2                                          40.157115
# 3                                          40.157115
# 4                                          40.157115
#
#    Cause of death, by injury (% of total)  \
# 0                               14.903117
# 1                               14.903117
# 2                               14.903117
# 3                               14.903117
# 4                               14.903117
#
#    Cause of death, by non-communicable diseases (% of total)  \
# 0                                          44.939767
# 1                                          44.939767
# 2                                          44.939767
# 3                                          44.939767
# 4                                          44.939767
#
#    Current health expenditure (% of GDP)  \
# 0                              10.223393
# 1                               7.897176
# 2                               8.561907
# 3                               8.805941
# 4                              11.818562
#
#    Current health expenditure per capita, PPP ( $)  \
# 0                                       163.917681
# 1                                       151.917984
# 2                                       143.091522
# 3                                       174.059479
# 4                                       234.140213
#
#    Death rate (per 1,000 people)  \
# 0                       8.211684
# 1                       7.645000
# 2                       7.936000
# 3                       7.380000
# 4                       6.742000
#
#    Diabetes prevalence (% of population ages 20 to 79)  \
# 0                                              10.90
# 1                                               9.25
# 2                                               7.60
# 3                                               9.25
# 4                                               9.25
#
#    Domestic general government health expenditure (% of GDP)  \
# 0                                           0.535133
# 1                                           0.342887
# 2                                           0.480000
# 3                                           0.443358
# 4                                           0.600128
#
#    Domestic general government health expenditure per capita, PPP ($)  \
# 0                                           8.692245
# 1                                           6.596119
# 2                                           8.022033
# 3                                           8.763480
# 4                                          11.889279
#
#    Domestic private health expenditure per capita, PPP  ($)  \
# 0                                         125.905373
# 1                                         113.157953
# 2                                         104.821934
# 3                                         125.406128
# 4                                         177.886491
#
#    External health expenditure per capita, PPP ($)  \
# 0                                        29.320065
# 1                                        32.163919
# 2                                        30.247552
# 3                                        39.889862
# 4                                        44.364468
#
#    Fertility rate, total (births per woman)   GDP (B$)  \
# 0                                  5.755316  19.700524
# 1                                  5.562000  59.656796
# 2                                  5.770000  57.314299
# 3                                  5.359000  61.367582
# 4                                  4.800000   0.000000
#
#    GDP per capita, PPP ($)  GNI per capita (US$)  \
# 0              6457.050021                 550.0
# 1              1848.700026                 630.0
# 2              1839.273579                 530.0
# 3              1838.960244                 650.0
# 4              1829.565008                 550.0
#
#    Hospital beds (per 1,000 people)  Human capital index (HCI) (scale 0-1)  \
# 0                          0.443125                               0.394258
# 1                          0.530000                               0.394258
# 2                          0.440000                               0.394258
# 3                          0.530000                               0.394258
# 4                          0.500000                               0.394258
#
#    Immunization, Pol3 (% children)  \
# 0                        62.894737
# 1                        67.000000
# 2                        68.000000
# 3                        64.000000
# 4                        71.000000
#
#    Immunization, measles second dose (% of children)  \
# 0                                               30.0
# 1                                               33.0
# 2                                               31.0
# 3                                               38.0
# 4                                               40.0
#
#    Incidence of HIV  (per 1,000  population)  \
# 0                                   0.028421
# 1                                   0.030000
# 2                                   0.030000
# 3                                   0.030000
# 4                                   0.040000
#
#    Incidence of tuberculosis (per 100,000 people)  \
# 0                                      189.210526
# 1                                      189.000000
# 2                                      189.000000
# 3                                      189.000000
# 4                                      189.000000
#
#    Life expectancy at birth, total (years)  \
# 0                                61.295789
# 1                                62.054000
# 2                                61.553000
# 3                                62.525000
# 4                                63.763000
#
#    Lifetime risk of maternal death (%)  \
# 0                             6.144000
# 1                             5.023027
# 2                             5.520806
# 3                             4.538151
# 4                             3.330914
#
#    Literacy rate, adult total (% of people ages 15 and above)  \
# 0                                          37.266041
# 1                                          34.357446
# 2                                          31.448851
# 3                                          34.357446
# 4                                          34.357446
#
#    Maternal mortality ratio ( per 100,000 live births)  \
# 0                                            963.625
# 1                                            858.000
# 2                                            905.000
# 3                                            810.000
# 4                                            673.000
#
#    Mortality caused by road traffic injury (per 100,000 people)  \
# 0                                          14.705556
# 1                                          13.800000
# 2                                          14.200000
# 3                                          14.000000
# 4                                          14.800000
#
#    Mortality from CVD, cancer, diabetes or CRD (%)  \
# 0                                        38.061111
# 1                                        36.600000
# 2                                        37.100000
# 3                                        36.200000
# 4                                        35.600000
#
#    Mortality rate, infant (per 1,000 live births)  Nurses (per 1,000 people)  \
# 0                                       63.105263                     0.3563
# 1                                       59.500000                     0.3563
# 2                                       61.800000                     0.3563
# 3                                       57.300000                     0.2495
# 4                                       51.300000                     0.1482
#
#    Out-of-pocket expenditure (% of current health expenditure)  \
# 0                                          77.517930
# 1                                          74.486206
# 2                                          73.255173
# 3                                          72.047867
# 4                                          75.974335
#
#    Out-of-pocket expenditure per capita, PPP ($)  \
# 0                                     125.873408
# 1                                     113.157953
# 2                                     104.821934
# 3                                     125.406128
# 4                                     177.886491
#
#    People using drinking water services (%)  Physicians (per 1,000 people)  \
# 0                                 51.484575                       0.236064
# 1                                 53.403517                       0.241400
# 2                                 50.827846                       0.251800
# 3                                 56.014043                       0.284600
# 4                                 64.054883                       0.278200
#
#    Population  Population growth (annual %)  Prevalence of HIV (%)  \
# 0   3051010.0                      2.303412                    0.1
# 1  32269592.0                      3.407600                    0.1
# 2  31161378.0                      3.143106                    0.1
# 3  33370804.0                      3.494592                    0.1
# 4  36296111.0                      2.778035                    0.1
#
#    Prevalence of anemia among children (%)  \
# 0                                44.644444
# 1                                43.500000
# 2                                43.500000
# 3                                43.500000
# 4                                43.900000
#
#    Prevalence of overweight ( % of children )  \
# 0                                    5.184211
# 1                                    5.300000
# 2                                    5.500000
# 3                                    5.200000
# 4                                    4.600000
#
#    Prevalence of overweight (% of adults)  Prevalence of tobacco  (%)  \
# 0                               18.873333                       26.45
# 1                               20.500000                       26.45
# 2                               19.900000                       26.45
# 3                               21.100000                       26.45
# 4                               23.000000                       26.45
#
#    Public spending on education (% of GDP)  Rural population (%)  \
# 0                                  3.30172                73.686
# 1                                  3.32000                75.840
# 2                                  3.46201                76.052
# 3                                  3.45446                75.627
# 4                                  3.51198                74.980
#
#    School enrollment, tertiary (%)  Suicide mortality rate (per 100,000)  \
# 0                         5.709476                              4.405556
# 1                         7.397240                              4.000000
# 2                         3.622260                              4.100000
# 3                         5.709476                              4.000000
# 4                         5.709476                              4.000000
#
#    Total alcohol consumption per capita   \
# 0                                   0.21
# 1                                   0.21
# 2                                   0.21
# 3                                   0.21
# 4                                   0.21
#
#    Tuberculosis death rate (per 100,000 people)  Unemployment, total (%)  \
# 0                                     41.105263                   13.283
# 1                                     44.000000                   11.341
# 2                                     44.000000                   11.054
# 3                                     43.000000                   11.193
# 4                                     34.000000                   11.158
#
#      Year
# 0  2021.0
# 1  2012.0
# 2  2011.0
# 3  2013.0
# 4  2016.0
# (1306, 10)

# %% [markdown]
# ## We keep 9 columns out of 15
# #### 1 Output to predict : Life expectancy at birth (years)
# ####  8 Features : those which has highest correlation to output and the lowest to each other to minimize the Noise & Overfitting

# %%
health2 =numerical_trimmed
health2.head()
# Out:
#    Cause of death, by communicable diseasesl and nutrition conditions (% of total)  \
# 0                                          40.157115
# 1                                          40.157115
# 2                                          40.157115
# 3                                          40.157115
# 4                                          40.157115
#
#    Fertility rate, total (births per woman)  \
# 0                                  5.755316
# 1                                  5.562000
# 2                                  5.770000
# 3                                  5.359000
# 4                                  4.800000
#
#    Incidence of HIV  (per 1,000  population)  \
# 0                                   0.028421
# 1                                   0.030000
# 2                                   0.030000
# 3                                   0.030000
# 4                                   0.040000
#
#    Incidence of tuberculosis (per 100,000 people)  \
# 0                                      189.210526
# 1                                      189.000000
# 2                                      189.000000
# 3                                      189.000000
# 4                                      189.000000
#
#    Life expectancy at birth, total (years)  \
# 0                                61.295789
# 1                                62.054000
# 2                                61.553000
# 3                                62.525000
# 4                                63.763000
#
#    Maternal mortality ratio ( per 100,000 live births)  \
# 0                                            963.625
# 1                                            858.000
# 2                                            905.000
# 3                                            810.000
# 4                                            673.000
#
#    Mortality rate, infant (per 1,000 live births)  \
# 0                                       63.105263
# 1                                       59.500000
# 2                                       61.800000
# 3                                       57.300000
# 4                                       51.300000
#
#    Out-of-pocket expenditure per capita, PPP ($)  \
# 0                                     125.873408
# 1                                     113.157953
# 2                                     104.821934
# 3                                     125.406128
# 4                                     177.886491
#
#    Prevalence of anemia among children (%)  School enrollment, tertiary (%)
# 0                                44.644444                         5.709476
# 1                                43.500000                         7.397240
# 2                                43.500000                         3.622260
# 3                                43.500000                         5.709476
# 4                                43.900000                         5.709476

# %% [markdown]
# ## Train/test/split data

# %%
### X,y split

y = health2["Life expectancy at birth, total (years)"]
x = health2.drop(["Life expectancy at birth, total (years)"], axis = 1)

# %%
### Train-test split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 80)
print(x_train.shape)
print(x_test.shape)
# Out:
# (914, 9)
# (392, 9)

# %% [markdown]
# ## Scaling & transformation

# %%
### Normaliyation by columns 

transformer = MinMaxScaler().fit(x_train)
x_train_norm = transformer.transform(x_train)
x_train_norm = pd.DataFrame(x_train_norm, columns=x_train.columns)
x_train_norm
# Out:
#      Cause of death, by communicable diseasesl and nutrition conditions (% of total)  \
# 0                                             0.085054
# 1                                             0.266255
# 2                                             0.165111
# 3                                             0.711206
# 4                                             0.019745
# ..                                                 ...
# 909                                           0.124728
# 910                                           0.843263
# 911                                           0.376889
# 912                                           0.138958
# 913                                           0.031905
#
#      Fertility rate, total (births per woman)  \
# 0                                    0.174158
# 1                                    0.284321
# 2                                    0.407283
# 3                                    0.588298
# 4                                    0.086698
# ..                                        ...
# 909                                  0.139266
# 910                                  0.628371
# 911                                  0.287064
# 912                                  0.218650
# 913                                  0.000000
#
#      Incidence of HIV  (per 1,000  population)  \
# 0                                     0.002209
# 1                                     0.058531
# 2                                     0.000000
# 3                                     0.003313
# 4                                     0.003865
# ..                                         ...
# 909                                   0.033131
# 910                                   0.120928
# 911                                   0.003313
# 912                                   0.008835
# 913                                   0.028713
#
#      Incidence of tuberculosis (per 100,000 people)  \
# 0                                          0.003993
# 1                                          0.067666
# 2                                          0.003082
# 3                                          0.178341
# 4                                          0.120902
# ..                                              ...
# 909                                        0.001401
# 910                                        0.195853
# 911                                        0.378678
# 912                                        0.069067
# 913                                        0.084477
#
#      Maternal mortality ratio ( per 100,000 live births)  \
# 0                                             0.007218
# 1                                             0.108277
# 2                                             0.025505
# 3                                             0.245910
# 4                                             0.017806
# ..                                                 ...
# 909                                           0.037536
# 910                                           0.296439
# 911                                           0.064485
# 912                                           0.014437
# 913                                           0.014918
#
#      Mortality rate, infant (per 1,000 live births)  \
# 0                                          0.029074
# 1                                          0.254017
# 2                                          0.121653
# 3                                          0.395562
# 4                                          0.143841
# ..                                              ...
# 909                                        0.082632
# 910                                        0.539403
# 911                                        0.166029
# 912                                        0.193573
# 913                                        0.092578
#
#      Out-of-pocket expenditure per capita, PPP ($)  \
# 0                                         0.317203
# 1                                         0.049985
# 2                                         0.187466
# 3                                         0.015152
# 4                                         0.229359
# ..                                             ...
# 909                                       0.066523
# 910                                       0.052394
# 911                                       0.116830
# 912                                       0.115844
# 913                                       0.097059
#
#      Prevalence of anemia among children (%)  School enrollment, tertiary (%)
# 0                                   0.146628                         0.797565
# 1                                   0.374046                         0.123272
# 2                                   0.267176                         0.462618
# 3                                   0.590331                         0.027819
# 4                                   0.265903                         0.578849
# ..                                       ...                              ...
# 909                                 0.184478                         0.261667
# 910                                 0.703562                         0.084718
# 911                                 0.092875                         0.375993
# 912                                 0.311705                         0.108616
# 913                                 0.217557                         0.637770
#
# [914 rows x 9 columns]

# %%
transformer = MinMaxScaler().fit(x_test)
x_test_norm = transformer.transform(x_test)
x_test_norm = pd.DataFrame(x_test_norm, columns=x_test.columns)
x_test_norm
# Out:
#      Cause of death, by communicable diseasesl and nutrition conditions (% of total)  \
# 0                                             0.082019
# 1                                             0.204004
# 2                                             0.086390
# 3                                             0.692490
# 4                                             0.018142
# ..                                                 ...
# 387                                           0.926654
# 388                                           0.176500
# 389                                           0.159911
# 390                                           0.141198
# 391                                           0.206493
#
#      Fertility rate, total (births per woman)  \
# 0                                    0.124517
# 1                                    0.057624
# 2                                    0.166847
# 3                                    0.543334
# 4                                    0.063958
# ..                                        ...
# 387                                  0.859416
# 388                                  0.259694
# 389                                  0.409238
# 390                                  0.306195
# 391                                  0.175807
#
#      Incidence of HIV  (per 1,000  population)  \
# 0                                     0.005394
# 1                                     0.012406
# 2                                     0.001079
# 3                                     0.004854
# 4                                     0.001079
# ..                                         ...
# 387                                   0.002157
# 388                                   0.011327
# 389                                   0.000000
# 390                                   0.000000
# 391                                   0.014024
#
#      Incidence of tuberculosis (per 100,000 people)  \
# 0                                          0.006493
# 1                                          0.116182
# 2                                          0.019731
# 3                                          0.151485
# 4                                          0.141398
# ..                                              ...
# 387                                        0.049991
# 388                                        0.034231
# 389                                        0.001891
# 390                                        0.009645
# 391                                        0.019101
#
#      Maternal mortality ratio ( per 100,000 live births)  \
# 0                                             0.018213
# 1                                             0.022766
# 2                                             0.024474
# 3                                             0.268071
# 4                                             0.022197
# ..                                                 ...
# 387                                           0.376850
# 388                                           0.051793
# 389                                           0.030165
# 390                                           0.023904
# 391                                           0.030734
#
#      Mortality rate, infant (per 1,000 live births)  \
# 0                                          0.056931
# 1                                          0.076733
# 2                                          0.099010
# 3                                          0.377063
# 4                                          0.204620
# ..                                              ...
# 387                                        0.352310
# 388                                        0.146865
# 389                                        0.130363
# 390                                        0.182343
# 391                                        0.119637
#
#      Out-of-pocket expenditure per capita, PPP ($)  \
# 0                                         0.207744
# 1                                         0.060537
# 2                                         0.243369
# 3                                         0.019810
# 4                                         0.189537
# ..                                             ...
# 387                                       0.022572
# 388                                       0.216804
# 389                                       0.247186
# 390                                       0.228599
# 391                                       0.147989
#
#      Prevalence of anemia among children (%)  School enrollment, tertiary (%)
# 0                                   0.076408                         0.561169
# 1                                   0.143432                         0.556595
# 2                                   0.207775                         0.395746
# 3                                   0.528150                         0.031716
# 4                                   0.276139                         0.492151
# ..                                       ...                              ...
# 387                                 0.857164                         0.041762
# 388                                 0.218499                         0.485962
# 389                                 0.229223                         0.430074
# 390                                 0.329759                         0.340880
# 391                                 0.146113                         0.284536
#
# [392 rows x 9 columns]

# %% [markdown]
# ## Apply the linear model & results

# %%
lm = LinearRegression()
lm.fit(x_train_norm, y_train)
y_pred_train = lm.predict(x_train_norm)
y_pred_test = lm.predict(x_test_norm)
y_pred_train = lm.predict(x_train_norm)
y_pred_test = lm.predict(x_test_norm)
r2_train = r2_score(y_pred_train, y_train)
r2_test = r2_score(y_pred_test, y_test)
mse_train = mean_squared_error(y_pred_train, y_train)
mse_test = mean_squared_error(y_pred_test, y_test)
mae_train = mean_absolute_error(y_pred_train, y_train)
mae_test = mean_absolute_error(y_pred_test, y_test)
mape_train = mean_absolute_percentage_error(y_pred_train, y_train)
mape_test = mean_absolute_percentage_error(y_pred_test, y_test)


print('\nResult model with split in ', '70/30')
print("R2 score of trained dataset is", round(r2_train,3))
print("R2 score of test dataset is", round(r2_test,3))

print("Mean absolute percentage error of train dataset is", round(mape_train, 2))
print("Mean absolute percentage error of test dataset is", round(mape_test, 2))
# Out:
# Result model with split in  70/30
# R2 score of trained dataset is 0.923
# R2 score of test dataset is 0.922
# Mean absolute percentage error of train dataset is 0.03
# Mean absolute percentage error of test dataset is 0.03

# %% [markdown]
# ## Apply DecisionTreeRegressor & Results

# %%
from sklearn.tree import DecisionTreeRegressor
regr = DecisionTreeRegressor(max_depth=10,
                             min_samples_split=10,
                             min_samples_leaf =5,
                             random_state = 42)
regr.fit(x_train, y_train)
print("Train data R2 was: {:.2f}".format(regr.score(x_train, y_train)))
print("Test data R2 was: {:.2f}".format(regr.score(x_test, y_test)))
# Out:
# Train data R2 was: 0.99
# Test data R2 was: 0.96

# %% [markdown]
# ## Apply KNeighborsRegressor & Results

# %%
from sklearn.neighbors import KNeighborsRegressor
regr = KNeighborsRegressor(n_neighbors=3)
regr.fit(x_train, y_train)
print("Train data R2 was: {:.2f}".format(regr.score(x_train, y_train)))
print("Test data R2 was: {:.2f}".format(regr.score(x_test, y_test)))
# Out:
# Train data R2 was: 0.97
# Test data R2 was: 0.93

# %% [markdown]
# # Hyperparameter search

# %% [markdown]
# ## Apply RandomForestRegressor + GridSearchCV & Result

# %%
from sklearn.model_selection import GridSearchCV

max_depth_choices= [8,10,12]
criterion_choices = ['squared_error','absolute_error'] 
min_samples_split_choices = [8,10,12] 
min_samples_leaf_choices = [5,6,7] 
# Create the  grid 
grid = {'max_depth': max_depth_choices,
        'criterion': criterion_choices,
        'min_samples_split': min_samples_split_choices,
        'min_samples_leaf': min_samples_leaf_choices}
# Instantiate the grid search model object
model = RandomForestRegressor()
grid_search = GridSearchCV(estimator = model, param_grid = grid, cv = 5)
# Fit the grid search to the data
grid_search.fit(x_train, y_train)
grid_search.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 12,
#  'min_samples_leaf': 5,
#  'min_samples_split': 10}

# %% [markdown]
# ### More detailed search : optimization parameters

# %%
max_depth_choices= [11,12,13]
criterion_choices = ['squared_error','absolute_error'] 
min_samples_split_choices = [9,10,11] 
min_samples_leaf_choices = [4,5,6] 
# Create the  grid 
grid = {'max_depth': max_depth_choices,
        'criterion': criterion_choices,
        'min_samples_split': min_samples_split_choices,
        'min_samples_leaf': min_samples_leaf_choices}
# Instantiate the grid search model object
model = RandomForestRegressor()
grid_search = GridSearchCV(estimator = model, param_grid = grid, cv = 5)
# Fit the grid search to the data
grid_search.fit(x_train, y_train)
grid_search.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 11,
#  'min_samples_leaf': 4,
#  'min_samples_split': 9}

# %% [markdown]
# ## Apply RandomForestRegressor model & Results

# %%
from sklearn.ensemble import RandomForestRegressor

clf = RandomForestRegressor(max_depth=11,
                             min_samples_split = 9,
                             min_samples_leaf =4,
                             max_samples=.9,
                             random_state = 42)
clf.fit(x_train_norm, y_train)

print("The R2 for the Random Forest in the TRAIN set is {:.2f}".format(clf.score(x_train_norm, y_train)))
print("The R2 for the Random Forest in the TEST  set is {:.2f}".format(clf.score(x_test_norm, y_test)))

y_pred = clf.predict(x_test_norm)
y_pred = clf.predict(x_test_norm)
print('\n\n Which feature impact the life expectancy?')
column_relevance = list(zip(np.abs(lm.coef_), x_train_norm.columns, np.round_(lm.coef_)))
column_relevance.sort(reverse=True)
column_relevance = [(item[1],item[-1]) for item in column_relevance]
column_relevance
# Out:
# The R2 for the Random Forest in the TRAIN set is 0.99
# The R2 for the Random Forest in the TEST  set is 0.98
#
#
#  Which feature impact the life expectancy?
# [('Incidence of HIV  (per 1,000  population)', -20.0),
#  ('Mortality rate, infant (per 1,000 live births)', -16.0),
#  ('Maternal mortality ratio ( per 100,000 live births)', -11.0),
#  ('Prevalence of anemia among children (%)', -6.0),
#  ('Fertility rate, total (births per woman)', -5.0),
#  ('Incidence of tuberculosis (per 100,000 people)', -4.0),
#  ('Out-of-pocket expenditure per capita, PPP ($)', 3.0),
#  ('School enrollment, tertiary (%)', -3.0),
#  ('Cause of death, by communicable diseasesl and nutrition conditions (% of total)',
#   -0.0)]

# %% [markdown]
# ## Apply RandomForestClassifier + cross_val_score & Result

# %%
from sklearn.model_selection import cross_val_score

y_true = y_train
clf = RandomForestRegressor(max_depth=11,
                             min_samples_split = 9,
                             min_samples_leaf =4,
                             max_samples=.9,
                             random_state = 42)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)

cross_val_scores = cross_val_score(clf, x_train, y_train, cv=5)

print("The mean R2 of the folds was {:.2f}".format(np.mean(cross_val_scores)))
# Out:
# The mean R2 of the folds was 0.97

# %% [markdown]
# ## RandomizedSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV

max_depth_choices= [8,10,12]
criterion_choices = ['squared_error','absolute_error'] 
min_samples_split_choices = [8,10,12] 
min_samples_leaf_choices = [5,6,7] 
# Create the  grid 
random_grid = {'max_depth': max_depth_choices,
        'criterion': criterion_choices,
        'min_samples_split': min_samples_split_choices,
        'min_samples_leaf': min_samples_leaf_choices}
# Instantiate the grid search model object
model = RandomForestRegressor()
random_search = RandomizedSearchCV(estimator = model, param_distributions = random_grid, n_iter=25, cv = 5, n_jobs = 10) 
random_search.fit(x_train, y_train)
random_search.best_params_
# Out:
# {'min_samples_split': 8,
#  'min_samples_leaf': 5,
#  'max_depth': 10,
#  'criterion': 'squared_error'}
